# %% [markdown]
# # YOLO11n-seg + SimAM+CA + Boundary-Aware Mask Loss (Nhóm B — B2)
#
# **Cải tiến:** Thay thế BCE Loss mặc định cho masks bằng BCE + Boundary IoU Loss.
# **Lý do:** BCE Loss đánh giá đều mọi pixel mà không phân biệt pixel biên giới (quan trọng) và pixel lõi (ít quan trọng). Boundary-Aware Loss cung cấp gradient trực tiếp cho vùng biên giới mask → mask boundary sắc nét hơn.
# **Kỳ vọng:** mAP50-95 tăng từ ~0.17 lên 0.22-0.28 nhờ gradient rõ ràng tại ranh giới BG/WSSV.
# **Base model:** SimAM+CA (best model từ notebook combined).

# %%
import importlib.util, subprocess, sys

if importlib.util.find_spec('roboflow') is None:
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', 'roboflow'])

if importlib.util.find_spec('ultralytics') is None:
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', 'ultralytics'])

print('Dependencies ready.')
# Out:
# Dependencies ready.

# %%
import torch
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
    print('VRAM:', round(torch.cuda.get_device_properties(0).total_memory / 1e9, 1), 'GB')
# Out:
# CUDA available: True
# GPU: Tesla T4
# VRAM: 15.6 GB

# %%
import os
from roboflow import Roboflow

ROBOFLOW_API_KEY_DIRECT = 'KOEk0qLzBFDc7zfyxtgs'
ROBOFLOW_WORKSPACE    = 'lets-try-this'
ROBOFLOW_PROJECT      = 'shrimpdishandsegv2'
ROBOFLOW_VERSION      = 1
ROBOFLOW_FORMAT       = 'yolo26'


def get_roboflow_api_key():
    if ROBOFLOW_API_KEY_DIRECT.strip():
        return ROBOFLOW_API_KEY_DIRECT.strip()
    try:
        from google.colab import userdata
        return userdata.get('ROBOFLOW_API_KEY')
    except Exception:
        pass
    return os.environ.get('ROBOFLOW_API_KEY', '').strip()


api_key = get_roboflow_api_key()
rf      = Roboflow(api_key=api_key)
dataset = rf.workspace(ROBOFLOW_WORKSPACE).project(ROBOFLOW_PROJECT).version(ROBOFLOW_VERSION).download(ROBOFLOW_FORMAT)

base_path = '/content/shrimpDisHandSegV2-1' if os.path.exists('/content') else '/kaggle/working/shrimpDisHandSegV2-1'
print('Dataset root:', base_path)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in shrimpDisHandSegV2-1 to yolo26:: 100%|██████████| 296064/296064 [00:09<00:00, 30622.41it/s]
# Extracting Dataset Version Zip to shrimpDisHandSegV2-1 in yolo26:: 100%|██████████| 2301/2301 [00:01<00:00, 1672.19it/s]
# Dataset root: /content/shrimpDisHandSegV2-1

# %%
# ── Grouped-stratified split (anti-leakage) — identical to baseline ────────
import re, shutil, random
from collections import defaultdict, Counter
from pathlib import Path

SEED = 42
IMAGE_EXTENSIONS = ('.jpg', '.jpeg', '.png', '.bmp', '.webp')
TRAIN_RATIO, VAL_RATIO = 0.80, 0.10
SHRIMP_NAME_PATTERN = re.compile(
    r'^(?P<disease>Healthy|BG|WSSV_BG|WSSV)-(?P<shrimp_id>.+)-img-(?P<img_num>\d+)$',
    re.IGNORECASE,
)

def normalize_roboflow_stem(stem):
    stem = re.sub(r'_(jpg|jpeg|png|bmp|webp)\.rf\.[0-9a-f]+$', '', stem, flags=re.IGNORECASE)
    return re.sub(r'\.rf\.[0-9a-f]+$', '', stem, flags=re.IGNORECASE)

def parse_shrimp_group_key(image_name):
    stem  = normalize_roboflow_stem(Path(image_name).stem)
    match = SHRIMP_NAME_PATTERN.match(stem)
    if not match:
        return f'unparsed::{stem}', 'unparsed', None, None
    d = match.group('disease')
    s = match.group('shrimp_id')
    return f'{d.lower()}::{s}', d, s, int(match.group('img_num'))

def image_files_in_split(split):
    d = Path(base_path) / split / 'images'
    return sorted(p for p in d.iterdir() if p.is_file() and p.suffix.lower() in IMAGE_EXTENSIONS)

def move_image_and_label(image_path, target_split):
    ti = Path(base_path) / target_split / 'images'; ti.mkdir(parents=True, exist_ok=True)
    tl = Path(base_path) / target_split / 'labels'; tl.mkdir(parents=True, exist_ok=True)
    ls = image_path.parent.parent / 'labels' / f'{image_path.stem}.txt'
    id_ = ti / image_path.name; ld = tl / f'{image_path.stem}.txt'
    if image_path.resolve() != id_.resolve(): shutil.move(str(image_path), str(id_))
    if ls.exists():
        if ls.resolve() != ld.resolve(): shutil.move(str(ls), str(ld))
    else:
        ld.write_text('')

def disease_for_group(filenames):
    return Counter(parse_shrimp_group_key(f)[1] for f in filenames).most_common(1)[0][0]

def split_one_stratum(items):
    n = len(items); tr = int(TRAIN_RATIO*n); va = int(VAL_RATIO*n); te = n-tr-va
    if n >= 3:
        if va == 0: va, tr = 1, tr-1
        if te == 0: te, tr = 1, tr-1
    if tr < 1 and n > 0: tr = 1
    while tr+va+te > n: tr -= 1
    return items[:tr], items[tr:tr+va], items[tr+va:]

def remove_yolo_label_caches(root):
    for p in Path(root).glob('**/*.cache'): p.unlink()

for split in ['train', 'valid', 'test']:
    for sub in ['images', 'labels']:
        os.makedirs(os.path.join(base_path, split, sub), exist_ok=True)

all_images = []
for split in ['train', 'valid', 'test']:
    all_images.extend(image_files_in_split(split))
for img in sorted(all_images):
    move_image_and_label(img, 'train')

groups = defaultdict(list)
for img in image_files_in_split('train'):
    gk, *_ = parse_shrimp_group_key(img.name)
    groups[gk].append(img.name)

strata = defaultdict(list)
for gk, fn in sorted(groups.items()):
    strata[disease_for_group(fn)].append((gk, fn))

split_to_groups = {'train': [], 'valid': [], 'test': []}
rng = random.Random(SEED)
for disease, items in sorted(strata.items()):
    items = sorted(items, key=lambda x: x[0]); rng.shuffle(items)
    tr, va, te = split_one_stratum(items)
    split_to_groups['train'].extend(tr)
    split_to_groups['valid'].extend(va)
    split_to_groups['test'].extend(te)
    print(f'  {disease}: {len(tr)} train, {len(va)} valid, {len(te)} test groups')

for split, sg in split_to_groups.items():
    for _, fns in sg:
        for fn in fns:
            move_image_and_label(Path(base_path)/'train'/'images'/fn, split)

g2s = {}
for split in ['train', 'valid', 'test']:
    for ip in image_files_in_split(split):
        gk, *_ = parse_shrimp_group_key(ip.name)
        prev = g2s.setdefault(gk, split)
        if prev != split:
            raise RuntimeError(f'Leakage: {gk} in {prev} and {split}')
print('Leakage check PASSED.')
remove_yolo_label_caches(base_path)
for split in ['train', 'valid', 'test']:
    print(f'  {split}: {len(image_files_in_split(split))} images')
# Out:
#   BG: 60 train, 7 valid, 8 test groups
#   Healthy: 113 train, 14 valid, 15 test groups
#   WSSV: 94 train, 11 valid, 13 test groups
#   WSSV_BG: 64 train, 8 valid, 9 test groups
# Leakage check PASSED.
#   train: 905 images
#   valid: 115 images
#   test: 129 images

# %%
import yaml
data_yaml_path = os.path.join(base_path, 'data.yaml')
with open(data_yaml_path) as f:
    cfg = yaml.safe_load(f)
cfg['train'] = f'{base_path}/train/images'
cfg['val']   = f'{base_path}/valid/images'
cfg['test']  = f'{base_path}/test/images'
with open(data_yaml_path, 'w') as f:
    yaml.dump(cfg, f)
print('data.yaml updated. Classes:', cfg.get('names'))
# Out:
# data.yaml updated. Classes: ['BG', 'WSSV']

# %%
# ── Patch Boundary-Aware Mask Loss into ultralytics ────────────────────────
import torch
import torch.nn as nn
import ultralytics.utils.loss as ult_loss


class BoundaryAwareMaskLoss(nn.Module):
    """BCE + Boundary IoU loss for sharper segmentation boundaries."""

    def __init__(self, boundary_weight=0.5, kernel_size=3):
        super().__init__()
        self.bce             = nn.BCEWithLogitsLoss(reduction='none')
        self.boundary_weight = boundary_weight
        pad = kernel_size // 2
        self.pool = nn.MaxPool2d(kernel_size, stride=1, padding=pad)

    def _extract_boundary(self, mask_prob):
        m       = mask_prob.unsqueeze(1)
        dilated = self.pool(m)
        eroded  = -self.pool(-m)
        return (dilated - eroded).squeeze(1)

    def forward(self, pred_logits, gt_masks, *args, **kwargs):
        bce_loss  = self.bce(pred_logits, gt_masks.float()).mean()

        pred_prob = pred_logits.sigmoid()
        pred_b    = self._extract_boundary(pred_prob)
        gt_b      = self._extract_boundary(gt_masks.float())

        inter         = (pred_b * gt_b).sum(dim=[1, 2])
        union         = pred_b.sum(dim=[1, 2]) + gt_b.sum(dim=[1, 2]) - inter
        boundary_iou  = (inter + 1e-7) / (union + 1e-7)
        boundary_loss = (1 - boundary_iou).mean()

        return bce_loss + self.boundary_weight * boundary_loss


_boundary_loss_fn = BoundaryAwareMaskLoss(boundary_weight=0.5)

_orig_seg_loss_cls = ult_loss.v8SegmentationLoss

# Use *args/**kwargs so the patch survives ultralytics signature changes.
# Assign _boundary_loss_fn (an nn.Module) directly — no lambda — so
# PyTorch's pickle can serialize it when saving checkpoints.
_orig_seg_loss_method = getattr(_orig_seg_loss_cls, 'calculate_segmentation_loss', None)

if _orig_seg_loss_method is not None:
    def _patched_calculate_segmentation_loss(self, *args, **kwargs):
        self.seg_loss = _boundary_loss_fn   # nn.Module: picklable, no lambda
        return _orig_seg_loss_method(self, *args, **kwargs)

    _orig_seg_loss_cls.calculate_segmentation_loss = _patched_calculate_segmentation_loss
    print('BoundaryAwareMaskLoss patched into v8SegmentationLoss.calculate_segmentation_loss.')
else:
    # Fallback: patch __init__ to replace seg_loss attribute
    _orig_init = _orig_seg_loss_cls.__init__
    def _new_init(self, *args, **kwargs):
        _orig_init(self, *args, **kwargs)
        self.seg_loss = _boundary_loss_fn   # nn.Module: picklable, no lambda
    _orig_seg_loss_cls.__init__ = _new_init
    print('BoundaryAwareMaskLoss patched via __init__ (fallback path).')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# BoundaryAwareMaskLoss patched into v8SegmentationLoss.calculate_segmentation_loss.

# %%
# ── Register SimAM + CoordAtt in ultralytics namespace ─────────────────────
# CoordAtt args in YAML: [c1, reduction] where c1 = ACTUAL scaled channels
# from the FROM layer (64/128/256 for YOLO11n with width_multiple=0.25).
# ultralytics passes YAML args directly for custom modules — c1 must match.

import torch
import torch.nn as nn
import ultralytics.nn.modules.conv as conv_module
import ultralytics.nn.modules as nn_modules
import ultralytics.nn.tasks as tasks_module


class SimAM(nn.Module):
    def __init__(self, c1=None, e_lambda=1e-4):
        super().__init__()
        self.e_lambda   = e_lambda
        self.activation = nn.Sigmoid()

    def forward(self, x):
        b, c, h, w = x.size()
        n = h * w - 1
        if n <= 0:
            return x
        x_mu  = x - x.mean(dim=[2, 3], keepdim=True)
        denom = 4 * (x_mu.pow(2).sum(dim=[2, 3], keepdim=True) / n + self.e_lambda)
        y     = x_mu.pow(2) / denom + 0.5
        return x * self.activation(y)


class CoordAtt(nn.Module):
    # Channel-preserving: output channels == input channels (c1).
    # No separate c2 — ultralytics YAML args are (c1, reduction).
    def __init__(self, c1, reduction=32):
        super().__init__()
        mip = max(8, c1 // reduction)
        self.conv1  = nn.Conv2d(c1, mip, 1, 1, 0)
        self.bn1    = nn.BatchNorm2d(mip)
        self.act    = nn.SiLU()
        self.conv_h = nn.Conv2d(mip, c1, 1, 1, 0)
        self.conv_w = nn.Conv2d(mip, c1, 1, 1, 0)

    def forward(self, x):
        identity = x
        n, c, h, w = x.size()
        x_h = x.mean(dim=3, keepdim=True)
        x_w = x.mean(dim=2, keepdim=True).permute(0, 1, 3, 2)
        y   = self.act(self.bn1(self.conv1(torch.cat([x_h, x_w], dim=2))))
        x_h, x_w = torch.split(y, [h, w], dim=2)
        x_w = x_w.permute(0, 1, 3, 2)
        a_h = self.conv_h(x_h).sigmoid()
        a_w = self.conv_w(x_w).sigmoid()
        return identity * a_h * a_w


for ns in [conv_module, nn_modules, tasks_module]:
    ns.SimAM    = SimAM
    ns.CoordAtt = CoordAtt
nn_modules.__all__ = list(set(list(getattr(nn_modules, '__all__', [])) + ['SimAM', 'CoordAtt']))
print('SimAM + CoordAtt registered.')
# Out:
# SimAM + CoordAtt registered.

# %%
# ── Write YAML ─────────────────────────────────────────────────────────────
# CoordAtt args: [c1, reduction] where c1 = ACTUAL channels after width scaling.
# YOLO11n: width_multiple=0.25 → layer 16=64ch, layer 19=128ch, layer 22=256ch.
import ultralytics
from pathlib import Path

YAML_CONTENT = """
# YOLO11n-seg + SimAM + CA head — Boundary-Aware Mask Loss experiment (Nhom B, B2)
nc: 2
scales:
  n: [0.50, 0.25, 1024]

backbone:
  - [-1, 1, Conv, [64, 3, 2]]
  - [-1, 1, Conv, [128, 3, 2]]
  - [-1, 2, C3k2, [256, False, 0.25]]
  - [-1, 1, Conv, [256, 3, 2]]
  - [-1, 2, C3k2, [512, False, 0.25]]
  - [-1, 1, Conv, [512, 3, 2]]
  - [-1, 2, C3k2, [512, True]]
  - [-1, 1, Conv, [1024, 3, 2]]
  - [-1, 2, C3k2, [1024, True]]
  - [-1, 1, SPPF, [1024, 5]]
  - [-1, 2, C2PSA, [1024]]

head:
  - [-1, 1, nn.Upsample, [None, 2, "nearest"]]
  - [[-1, 6], 1, Concat, [1]]
  - [-1, 2, C3k2, [512, False]]

  - [-1, 1, nn.Upsample, [None, 2, "nearest"]]
  - [[-1, 4], 1, Concat, [1]]
  - [-1, 2, C3k2, [256, False]]

  - [-1, 1, Conv, [256, 3, 2]]
  - [[-1, 13], 1, Concat, [1]]
  - [-1, 2, C3k2, [512, False]]

  - [-1, 1, Conv, [512, 3, 2]]
  - [[-1, 10], 1, Concat, [1]]
  - [-1, 2, C3k2, [1024, True]]

  - [16, 1, CoordAtt, [64, 32]]
  - [23, 1, SimAM, []]

  - [19, 1, CoordAtt, [128, 32]]
  - [25, 1, SimAM, []]

  - [22, 1, CoordAtt, [256, 32]]
  - [27, 1, SimAM, []]

  - [[24, 26, 28], 1, Segment, [nc, 32, 256]]
""".strip()

ultralytics_root = Path(ultralytics.__file__).parent
yaml_dir  = ultralytics_root / 'cfg' / 'models' / '11'
yaml_dir.mkdir(parents=True, exist_ok=True)
yaml_path = yaml_dir / 'yolo11n-seg-simam-ca-boundary.yaml'
yaml_path.write_text(YAML_CONTENT)
print('YAML written to:', yaml_path)
# Out:
# YAML written to: /usr/local/lib/python3.12/dist-packages/ultralytics/cfg/models/11/yolo11n-seg-simam-ca-boundary.yaml

# %%
# ── Helper functions ───────────────────────────────────────────────────────
import gc, time, shutil
import yaml, pandas as pd
from pathlib import Path
from ultralytics import YOLO
from IPython.display import display

EXPERIMENT_ROOT = Path('/content/shrimp_boundary') if os.path.exists('/content') else Path('/kaggle/working/shrimp_boundary')
RUNS_DIR   = EXPERIMENT_ROOT / 'runs' / 'segment'
REPORT_DIR = EXPERIMENT_ROOT / 'reports'
REPORT_DIR.mkdir(parents=True, exist_ok=True)

COUNT_PENALTY_WEIGHT       = 0.05
DISEASE_MISS_PENALTY_WEIGHT = 0.15
HEALTHY_FP_PENALTY_WEIGHT  = 0.10
PREDICT_CONF_FOR_COUNT     = 0.25
TRAIN_IMGSZ = 640


def find_image_for_label(image_dir, label_name):
    stem = Path(label_name).stem
    for ext in IMAGE_EXTENSIONS:
        c = Path(image_dir) / f'{stem}{ext}'
        if c.exists(): return c
    return None

def write_data_yaml(dataset_dir, out_yaml):
    with open(data_yaml_path) as f: c = yaml.safe_load(f)
    c['train'] = str(Path(dataset_dir)/'train'/'images')
    c['val']   = str(Path(dataset_dir)/'valid'/'images')
    c['test']  = str(Path(dataset_dir)/'test'/'images')
    with open(out_yaml, 'w') as f: yaml.safe_dump(c, f, sort_keys=False)

def copy_dataset_for_experiment(exp_key):
    dst = EXPERIMENT_ROOT / exp_key / 'dataset'
    if dst.exists(): shutil.rmtree(dst)
    shutil.copytree(base_path, dst, ignore=shutil.ignore_patterns('*.cache'))
    remove_yolo_label_caches(dst)
    return dst

def copy_split_by_label_state(src, dst, split, want_labeled):
    si = Path(src)/split/'images'; sl = Path(src)/split/'labels'
    di = Path(dst)/split/'images'; dl = Path(dst)/split/'labels'
    di.mkdir(parents=True, exist_ok=True); dl.mkdir(parents=True, exist_ok=True)
    copied = 0
    for lp in sorted(sl.glob('*.txt')):
        lines = [l.strip() for l in lp.read_text().splitlines() if l.strip()]
        if bool(lines) != want_labeled: continue
        ip = find_image_for_label(si, lp.name)
        if ip is None: continue
        shutil.copy2(ip, di/ip.name); shutil.copy2(lp, dl/lp.name); copied += 1
    return copied

def make_eval_dataset(src, exp_key, state_name, want_labeled):
    dst = EXPERIMENT_ROOT/exp_key/f'dataset_{state_name}_eval'
    if dst.exists(): shutil.rmtree(dst)
    for sub in ['images','labels']: (dst/'train'/sub).mkdir(parents=True, exist_ok=True)
    for split in ['valid','test']: copy_split_by_label_state(src, dst, split, want_labeled)
    yp = dst/f'data_{state_name}.yaml'; write_data_yaml(dst, yp)
    return dst, yp

def metric_value(metrics, dotted_path, default=float('nan')):
    obj = metrics
    for part in dotted_path.split('.'):
        if not hasattr(obj, part): return default
        obj = getattr(obj, part)
    try: return float(obj)
    except: return default

def count_prediction_errors(model, images_dir, labels_dir, conf=PREDICT_CONF_FOR_COUNT):
    ips = sorted(p for p in Path(images_dir).iterdir() if p.suffix.lower() in IMAGE_EXTENSIONS)
    if not ips:
        nan = float('nan')
        return dict(images=0, gt_total=0, pred_mask_total=0, mask_count_mae=nan,
                    disease_images=0, disease_box_miss_rate=nan, disease_mask_miss_rate=nan)
    results = model.predict(source=[str(p) for p in ips], imgsz=TRAIN_IMGSZ, conf=conf, verbose=False)
    errs, di, dbm = [], 0, 0; gt_total = pred_total = 0
    for ip, res in zip(ips, results):
        lp = Path(labels_dir)/f'{ip.stem}.txt'
        gt = len([l for l in lp.read_text().splitlines() if l.strip()]) if lp.exists() else 0
        pm = len(res.masks) if res.masks is not None else 0
        pb = len(res.boxes) if res.boxes is not None else 0
        errs.append(abs(pm-gt)/max(1,gt))
        if gt > 0: di += 1; dbm += int(pb == 0)
        gt_total += gt; pred_total += pm
    return dict(images=len(ips), gt_total=gt_total, pred_mask_total=pred_total,
                mask_count_mae=sum(errs)/len(errs) if errs else float('nan'),
                disease_images=di,
                disease_box_miss_rate=dbm/di if di else float('nan'),
                disease_mask_miss_rate=float('nan'))

def healthy_false_positive_summary(model, images_dir, conf=PREDICT_CONF_FOR_COUNT):
    ips = sorted(p for p in Path(images_dir).iterdir() if p.suffix.lower() in IMAGE_EXTENSIONS)
    if not ips:
        return dict(healthy_images=0, healthy_mask_fp_rate=float('nan'),
                    healthy_fp_masks_per_image=float('nan'), healthy_avg_fp_confidence=0.0)
    results = model.predict(source=[str(p) for p in ips], imgsz=TRAIN_IMGSZ, conf=conf, verbose=False)
    with_fp = mt = 0; confs = []
    for res in results:
        mc = len(res.masks) if res.masks is not None else 0
        if mc > 0:
            with_fp += 1; mt += mc
            try: confs.extend(res.boxes.conf.cpu().tolist())
            except: pass
    n = len(ips)
    return dict(healthy_images=n, healthy_mask_fp_rate=with_fp/n,
                healthy_fp_masks_per_image=mt/n,
                healthy_avg_fp_confidence=sum(confs)/len(confs) if confs else 0.0)

def healthy_aware_score(lm50, ci, fpi):
    return lm50 - COUNT_PENALTY_WEIGHT*ci['mask_count_mae'] - DISEASE_MISS_PENALTY_WEIGHT*ci['disease_box_miss_rate'] - HEALTHY_FP_PENALTY_WEIGHT*fpi['healthy_mask_fp_rate']

def read_best_epoch_from_results(run_path):
    csv_path = Path(run_path)/'results.csv'
    if not csv_path.exists(): return {}
    df = pd.read_csv(csv_path); df.columns = [c.strip() for c in df.columns]
    mc = 'metrics/mAP50(M)'
    if mc not in df.columns: return {'epochs_ran': len(df)}
    bi = df[mc].idxmax(); best = df.iloc[bi]; last = df.iloc[-1]
    return dict(epochs_ran=len(df),
                best_epoch_by_mask_map50=int(best.get('epoch', bi+1)),
                best_val_mask_map50=float(best.get(mc, float('nan'))),
                last_train_seg_loss=float(last.get('train/seg_loss', float('nan'))),
                last_val_seg_loss=float(last.get('val/seg_loss', float('nan'))),
                seg_loss_gap_val_minus_train=float(last.get('val/seg_loss',0)-last.get('train/seg_loss',0)))

def disable_ultralytics_albumentations():
    try:
        import ultralytics.data.augment as aug
        class _NoOp:
            contains_spatial = False
            def __init__(self, *a, **kw): self.transform = None
            def __call__(self, labels): return labels
        aug.Albumentations = _NoOp
    except Exception as e:
        print('Albumentations patch skipped:', e)

print('Helper functions defined.')
# Out:
# Helper functions defined.

# %%
# ── Training — SimAM+CA + Boundary-Aware Mask Loss ─────────────────────────
CLEAN_TRAIN_ARGS = dict(
    auto_augment=None,
    erasing=0.0, mosaic=0.0, mixup=0.0, cutmix=0.0, copy_paste=0.0,
    fliplr=0.5, flipud=0.0,
    hsv_h=0.01, hsv_s=0.35, hsv_v=0.20,
    degrees=0.0, translate=0.05, scale=0.20,
    shear=0.0, perspective=0.0, multi_scale=0.0, bgr=0.0,
)

exp_key  = 'simam_ca_boundary'
run_name = f'yolo11n-seg_{exp_key}'

dataset_dir = copy_dataset_for_experiment(exp_key)
exp_yaml    = dataset_dir / 'data.yaml'
write_data_yaml(dataset_dir, exp_yaml)

labeled_eval_dir, labeled_eval_yaml = make_eval_dataset(dataset_dir, exp_key, 'labeled_only', True)
healthy_eval_dir, healthy_eval_yaml = make_eval_dataset(dataset_dir, exp_key, 'healthy_only', False)

disable_ultralytics_albumentations()

yolo = YOLO(str(yaml_path))
try:
    yolo.load('yolo11n-seg.pt')
except Exception as e:
    print('Pretrained load warning:', e)

start = time.time()
yolo.train(
    data=str(exp_yaml),
    task='segment',
    imgsz=TRAIN_IMGSZ,
    epochs=100,
    batch=16,
    patience=30,
    seed=42,
    deterministic=True,
    workers=0,
    project=str(RUNS_DIR),
    name=run_name,
    exist_ok=True,
    pretrained=True,
    plots=True,
    verbose=True,
    **CLEAN_TRAIN_ARGS,
)
train_time_min = (time.time() - start) / 60
print(f'Training finished in {train_time_min:.1f} min.')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n-seg.pt to 'yolo11n-seg.pt': 100% ━━━━━━━━━━━━ 5.9MB 4.6MB/s 1.3s
# Transferred 378/594 items from pretrained weights
# Ultralytics 8.4.67 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=None, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/shrimp_boundary/simam_ca_boundary/dataset/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.0, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.01, hsv_s=0.35, hsv_v=0.2, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/models/11/yolo11n-seg-simam-ca-boundary.yaml, momentum=0.937, mosaic=0.0, multi_scale=0.0, name=yolo11n-seg_simam_ca_boundary, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/shrimp_boundary/runs/segment, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/shrimp_boundary/runs/segment/yolo11n-seg_simam_ca_boundary, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.2, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=botsort.yaml, translate=0.05, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 25.3MB/s 0.0s
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23                  16  1      1688  CoordAtt                                     [64, 32]
#  24                  23  1         0  SimAM                                        []
#  25                  19  1      3352  CoordAtt                                     [128, 32]
#  26                  25  1         0  SimAM                                        []
#  27                  22  1      6680  CoordAtt                                     [256, 32]
#  28                  27  1         0  SimAM                                        []
#  29        [24, 26, 28]  1    683830  ultralytics.nn.modules.head.Segment          [2, 32, 64, 16, None, [64, 128, 256]]
# YOLO11n-seg-simam-ca-boundary summary: 222 layers, 2,854,718 parameters, 2,854,702 gradients, 9.7 GFLOPs
#
# Transferred 594/594 items from pretrained weights
# Freezing layer 'model.29.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 102.3MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2085.2±1299.6 MB/s, size: 348.8 KB)
# train: Scanning /content/shrimp_boundary/simam_ca_boundary/dataset/train/labels... 905 images, 321 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 905/905 2.1Kit/s 0.4s
# train: New cache created: /content/shrimp_boundary/simam_ca_boundary/dataset/train/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3811.0±1043.3 MB/s, size: 505.9 KB)
# val: Scanning /content/shrimp_boundary/simam_ca_boundary/dataset/valid/labels... 115 images, 41 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 115/115 2.4Kit/s 0.0s
# val: New cache created: /content/shrimp_boundary/simam_ca_boundary/dataset/valid/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 93 weight(decay=0.0), 110 weight(decay=0.0005), 112 bias(decay=0.0)
# Plotting labels to /content/shrimp_boundary/runs/segment/yolo11n-seg_simam_ca_boundary/labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /content/shrimp_boundary/runs/segment/yolo11n-seg_simam_ca_boundary
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       1/100      2.99G      3.412      5.087       6.47      4.036          0          8        640: 100% ━━━━━━━━━━━━ 57/57 1.1s/it 1:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.3s/it 9.2s
#                    all        115        102          0          0          0          0          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       2/100      3.59G      2.816      4.525      4.852       3.37          0          7        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1it/s 3.5s
#                    all        115        102   2.43e-05     0.0109   7.61e-07   1.52e-07   4.86e-05     0.0217   2.44e-06   3.14e-07
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       3/100      3.59G      2.669      4.444      4.265      2.958          0         13        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1it/s 3.6s
#                    all        115        102      0.696     0.0357     0.0914     0.0228      0.696     0.0357     0.0881     0.0224
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       4/100      3.59G      2.641      4.428      3.639      2.878          0          8        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.4s
#                    all        115        102      0.162      0.222     0.0732     0.0241     0.0941      0.218     0.0552     0.0152
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       5/100      3.59G      2.579      4.328      3.166        2.8          0         10        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.4s
#                    all        115        102      0.285      0.269      0.222     0.0845       0.27      0.242      0.198     0.0543
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       6/100      3.59G      2.499      4.186       2.76      2.739          0         10        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.3s
#                    all        115        102      0.292      0.245      0.201     0.0634      0.249      0.169      0.142     0.0477
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       7/100      3.59G      2.517      4.103      2.519      2.695          0          7        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.3s
#                    all        115        102      0.276      0.309      0.229     0.0851      0.262      0.259      0.185     0.0614
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       8/100      3.59G      2.395      3.999      2.357      2.611          0          6        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.3s
#                    all        115        102      0.378      0.381      0.288     0.0835      0.328      0.318      0.244     0.0663
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       9/100      3.59G       2.41      3.954      2.233      2.609          0          6        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.4s
#                    all        115        102      0.367      0.362      0.277     0.0956      0.273      0.275      0.223     0.0741
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      10/100      3.59G      2.339      3.899      2.137      2.543          0          9        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 40.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.4s
#                    all        115        102       0.31      0.366      0.271     0.0952      0.231      0.299      0.196     0.0585
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      11/100      3.59G      2.298      3.827      2.052      2.513          0         11        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 40.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.0s/it 4.0s
#                    all        115        102      0.477      0.388       0.34      0.125      0.412      0.334      0.298     0.0857
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      12/100      3.59G      2.236      3.762      1.999      2.481          0          3        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 40.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.3s
#                    all        115        102      0.469      0.366      0.352      0.153      0.442      0.355      0.313      0.101
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      13/100      3.59G      2.216      3.597      1.906      2.458          0          7        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.0s/it 4.1s
#                    all        115        102      0.604      0.434      0.425       0.15      0.494      0.384      0.348      0.108
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      14/100      3.59G      2.153      3.609      1.865      2.422          0         11        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.3s
#                    all        115        102      0.626      0.477      0.469      0.169      0.511      0.423      0.395      0.126
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      15/100      3.59G      2.101       3.54       1.81      2.377          0         10        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.0it/s 3.9s
#                    all        115        102      0.652        0.3       0.37      0.128      0.425      0.312      0.298     0.0996
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      16/100      3.59G      2.107      3.478      1.776      2.371          0          8        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.2s
#                    all        115        102      0.562      0.382      0.434      0.173      0.546      0.332       0.37      0.127
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      17/100      3.59G      2.059      3.414      1.772      2.325          0          9        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.0it/s 3.9s
#                    all        115        102      0.552      0.406      0.424       0.16      0.468      0.307      0.307      0.112
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      18/100      3.59G      2.044      3.381      1.761      2.329          0          5        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.2s
#                    all        115        102      0.489      0.389      0.397      0.153      0.462       0.35      0.333       0.11
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      19/100      3.59G      2.034      3.313      1.695      2.307          0          8        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1it/s 3.6s
#                    all        115        102      0.438      0.311       0.37      0.125      0.439      0.272      0.323     0.0997
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      20/100      3.59G       2.03      3.293      1.639      2.303          0          6        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.2s
#                    all        115        102      0.475      0.428       0.37      0.147      0.444      0.387      0.323      0.105
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      21/100      3.59G      2.023      3.342      1.651      2.298          0          8        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.2s
#                    all        115        102      0.553      0.386      0.413       0.16      0.478       0.31      0.291      0.104
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      22/100      3.59G      1.988      3.246      1.572      2.267          0          8        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.4s
#                    all        115        102      0.537      0.459      0.417       0.16      0.546      0.425      0.391      0.124
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      23/100      3.59G      1.943      3.142      1.558      2.217          0          5        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.4s
#                    all        115        102      0.502      0.378      0.401       0.16      0.451       0.43       0.38      0.125
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      24/100      3.59G      1.907      3.109      1.511      2.201          0          9        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.2s
#                    all        115        102      0.452      0.507      0.429       0.16      0.516      0.378      0.366      0.122
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      25/100      3.59G       1.93      3.128      1.509      2.213          0          9        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.2s
#                    all        115        102      0.481      0.349      0.388      0.169      0.411      0.356      0.355      0.131
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      26/100      3.59G      1.906      3.109      1.496      2.172          0         10        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.4s
#                    all        115        102      0.595      0.439       0.48      0.193      0.566      0.425      0.427      0.151
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      27/100      3.59G      1.884      3.094      1.458      2.175          0          9        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.2s
#                    all        115        102      0.478      0.447      0.439      0.166      0.402      0.376      0.353      0.106
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      28/100      3.59G      1.851      3.023      1.419      2.146          0          8        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1it/s 3.8s
#                    all        115        102      0.465      0.432       0.42      0.155        0.5      0.373      0.398      0.133
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      29/100      3.59G      1.814      2.993      1.396      2.124          0          9        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.2s
#                    all        115        102      0.603      0.433      0.472      0.203      0.512      0.452      0.438      0.151
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      30/100      3.59G      1.826      2.938      1.351      2.118          0          8        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1it/s 3.7s
#                    all        115        102      0.543      0.486      0.482      0.185      0.505      0.452      0.441      0.138
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      31/100      3.59G      1.778      2.878      1.335      2.094          0          5        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.3s
#                    all        115        102      0.665      0.453      0.498      0.196      0.602       0.46      0.454      0.153
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      32/100      3.59G      1.761      2.866      1.337      2.079          0         11        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.2s
#                    all        115        102      0.631      0.346      0.434      0.189      0.641      0.324      0.382      0.133
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      33/100      3.59G      1.752      2.842       1.36      2.058          0          9        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.4s
#                    all        115        102      0.682      0.359       0.43      0.178      0.673      0.356      0.388      0.142
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      34/100      3.59G      1.736      2.837      1.276      2.034          0          5        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 40.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1it/s 3.5s
#                    all        115        102      0.566      0.434      0.452      0.174      0.493      0.401      0.393      0.124
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      35/100      3.59G      1.736       2.76      1.285      2.053          0          8        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.4s
#                    all        115        102      0.669      0.458      0.517        0.2       0.65      0.405       0.46      0.151
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      36/100      3.59G      1.718        2.8      1.264      2.022          0         12        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.0it/s 3.9s
#                    all        115        102      0.552      0.424      0.431      0.174      0.603      0.363      0.376      0.125
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      37/100      3.59G      1.656      2.706       1.24      1.989          0          8        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.2s
#                    all        115        102      0.512      0.444      0.429      0.169       0.56      0.332      0.369      0.114
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      38/100      3.59G      1.643      2.692      1.207      1.992          0          7        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.2s
#                    all        115        102      0.523      0.421      0.432      0.174      0.488      0.395      0.392       0.12
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      39/100      3.59G      1.687      2.659      1.218      2.005          0          6        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.1s
#                    all        115        102      0.671      0.415      0.465      0.177      0.611      0.382      0.411      0.127
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      40/100      3.59G      1.664      2.684      1.207      1.983          0          9        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.2s
#                    all        115        102      0.603      0.495      0.526      0.168      0.598      0.366      0.432       0.12
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      41/100      3.59G      1.604      2.643       1.17      1.951          0          7        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1it/s 3.5s
#                    all        115        102      0.675      0.404      0.476      0.173      0.643      0.342      0.386      0.109
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      42/100      3.59G      1.622      2.626      1.179      1.957          0          3        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.3s
#                    all        115        102      0.658        0.4      0.463      0.177      0.532      0.338      0.379      0.134
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      43/100      3.59G      1.547      2.598      1.132      1.868          0          8        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1it/s 3.7s
#                    all        115        102      0.596      0.418      0.424      0.153      0.637      0.393      0.388      0.123
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      44/100      3.59G      1.574      2.592      1.129      1.897          0          3        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.2s
#                    all        115        102      0.553      0.439      0.424      0.154      0.504      0.401      0.349      0.103
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      45/100      3.59G      1.543      2.561      1.125      1.881          0          9        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1it/s 3.8s
#                    all        115        102      0.407      0.504      0.442      0.162      0.504       0.43      0.399      0.126
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      46/100      3.59G      1.553      2.564      1.117      1.887          0          9        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.2s
#                    all        115        102      0.602      0.458      0.476      0.166      0.604      0.396      0.435      0.129
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      47/100      3.59G      1.532      2.484      1.086      1.871          0          7        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.0s/it 4.0s
#                    all        115        102      0.534      0.502      0.473      0.181      0.508      0.449       0.44      0.153
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      48/100      3.59G      1.544      2.495      1.091      1.862          0          8        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 40.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.4s
#                    all        115        102       0.49       0.49       0.48       0.19      0.507      0.485      0.447      0.144
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      49/100      3.59G        1.5      2.481      1.044      1.835          0          7        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1it/s 3.8s
#                    all        115        102      0.632      0.395       0.44      0.147      0.589       0.37      0.358      0.102
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      50/100      3.59G      1.486      2.439      1.027      1.825          0          7        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.2s
#                    all        115        102      0.568      0.416      0.461      0.176      0.603      0.396      0.426       0.14
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      51/100      3.59G      1.488       2.43      1.038      1.817          0         13        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.0it/s 3.9s
#                    all        115        102      0.614      0.477      0.484      0.189      0.687      0.413      0.429      0.143
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      52/100      3.59G      1.472       2.37      0.994      1.791          0          6        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.2s
#                    all        115        102      0.563      0.486      0.482      0.188      0.533      0.441       0.45       0.15
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      53/100      3.59G      1.401      2.365     0.9689      1.753          0          7        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1it/s 3.6s
#                    all        115        102      0.508      0.511      0.494       0.19      0.633      0.375      0.419      0.152
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      54/100      3.59G      1.446      2.397     0.9779      1.784          0         11        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.2s
#                    all        115        102      0.609      0.485      0.506      0.195       0.64      0.419      0.439      0.159
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      55/100      3.59G      1.428      2.389     0.9751      1.761          0          8        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.2s
#                    all        115        102      0.689      0.423      0.457      0.182      0.691      0.414      0.415      0.148
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      56/100      3.59G        1.4      2.367     0.9509      1.748          0          6        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.4s
#                    all        115        102      0.732      0.456      0.521      0.188      0.662      0.418      0.458      0.132
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      57/100      3.59G        1.4      2.325      0.957      1.739          0          7        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1it/s 3.6s
#                    all        115        102      0.511      0.412       0.44      0.161      0.617      0.323      0.369      0.107
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      58/100      3.59G      1.367      2.279     0.9292      1.719          0          6        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 40.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.4s
#                    all        115        102      0.602      0.469      0.498      0.181      0.678      0.426      0.452      0.141
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      59/100      3.59G      1.339      2.258     0.8961      1.681          0          7        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.0s/it 4.1s
#                    all        115        102      0.587      0.437      0.477      0.172      0.528      0.425      0.426      0.128
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      60/100      3.59G       1.34       2.26     0.9057      1.681          0          6        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.3s
#                    all        115        102      0.602      0.498      0.477      0.177       0.58      0.476      0.446      0.151
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      61/100      3.59G      1.329      2.202     0.9036      1.672          0         12        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.0it/s 4.0s
#                    all        115        102      0.545      0.454      0.481      0.192      0.649      0.404      0.448      0.149
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      62/100      3.59G      1.337      2.196     0.8877      1.684          0          7        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1it/s 3.5s
#                    all        115        102      0.551      0.472      0.489      0.184      0.552      0.456      0.429      0.143
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      63/100      3.59G       1.31      2.197     0.8682      1.669          0          7        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.0it/s 4.0s
#                    all        115        102      0.652      0.456      0.482      0.173      0.574      0.407      0.413      0.133
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      64/100      3.59G      1.295      2.136     0.8522      1.646          0          3        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.4s
#                    all        115        102      0.546      0.517      0.507      0.177      0.501      0.447      0.421      0.136
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      65/100      3.59G      1.281      2.174     0.8523      1.631          0          9        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.0it/s 3.9s
#                    all        115        102      0.791      0.456      0.527      0.194      0.708      0.406       0.43      0.139
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      66/100      3.59G      1.269      2.138     0.8442      1.623          0          4        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.3s
#                    all        115        102      0.734       0.52      0.565      0.215      0.614      0.429      0.452      0.148
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      67/100      3.59G       1.25      2.133     0.8207      1.594          0          9        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 41.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1it/s 3.5s
#                    all        115        102      0.628      0.494      0.504      0.171      0.557      0.424      0.435      0.138
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      68/100      3.59G      1.253      2.106     0.8261      1.592          0          8        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.3s
#                    all        115        102      0.681      0.482      0.532      0.191      0.698      0.407      0.469      0.142
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      69/100      3.59G       1.24      2.093     0.8187      1.593          0          4        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 40.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.3s
#                    all        115        102      0.675      0.459      0.515      0.194      0.645      0.368      0.414      0.149
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      70/100      3.59G      1.247      2.092      0.809      1.597          0         10        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.2s
#                    all        115        102      0.655       0.44      0.491      0.187      0.604      0.409      0.431      0.138
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      71/100      3.59G      1.207      2.003     0.8139      1.563          0          4        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.4s
#                    all        115        102      0.541      0.538      0.502      0.188      0.476      0.486      0.437       0.15
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      72/100      3.59G      1.178      1.988     0.7953      1.541          0          7        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.1s
#                    all        115        102      0.758      0.447      0.528      0.209      0.637      0.411      0.447      0.146
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      73/100      3.59G      1.185      2.015     0.7758      1.543          0         12        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1it/s 3.5s
#                    all        115        102      0.639      0.521      0.492      0.171      0.514      0.425      0.403      0.123
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      74/100      3.59G      1.176      1.969     0.7816       1.53          0          5        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.3s
#                    all        115        102      0.677      0.465      0.516      0.191      0.661      0.401      0.426      0.141
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      75/100      3.59G       1.14      1.988     0.7522        1.5          0          8        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 39.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1it/s 3.6s
#                    all        115        102      0.516      0.539      0.506      0.204      0.531      0.454      0.431      0.154
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      76/100      3.59G      1.152      1.991     0.7673      1.513          0          4        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.2s
#                    all        115        102      0.622       0.55      0.547      0.203      0.697      0.447      0.462       0.15
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      77/100      3.59G      1.134      1.931     0.7615      1.501          0          8        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1it/s 3.8s
#                    all        115        102       0.57      0.484      0.519      0.211      0.699      0.457      0.485      0.162
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      78/100      3.59G      1.126      1.949     0.7456       1.49          0          6        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.2s
#                    all        115        102      0.693      0.476      0.533      0.203      0.619       0.44       0.44      0.145
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      79/100      3.59G      1.116      1.914     0.7465      1.483          0          7        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.0it/s 3.8s
#                    all        115        102      0.669      0.546       0.55        0.2      0.564      0.467      0.442      0.148
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      80/100      3.59G      1.096      1.913     0.7309      1.454          0         10        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.2s
#                    all        115        102      0.697      0.463      0.508      0.187      0.607      0.427      0.426      0.135
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      81/100      3.59G      1.083      1.883     0.7139      1.458          0          7        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.0it/s 4.0s
#                    all        115        102      0.607       0.43      0.465      0.186      0.658      0.427      0.416       0.14
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      82/100      3.59G      1.073      1.875     0.7176      1.448          0          4        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.2s
#                    all        115        102      0.611      0.488      0.511      0.196      0.568       0.46      0.436      0.142
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      83/100      3.59G       1.07      1.853     0.7167      1.448          0          7        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.0it/s 3.9s
#                    all        115        102      0.556      0.506      0.493      0.198      0.543      0.447      0.442      0.159
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      84/100      3.59G      1.051      1.828     0.6972      1.426          0          7        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.2s
#                    all        115        102      0.607      0.574      0.544      0.211      0.696      0.451      0.469      0.154
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      85/100      3.59G      1.036      1.787     0.6874      1.413          0          6        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1it/s 3.6s
#                    all        115        102        0.5       0.53      0.505        0.2      0.613      0.427      0.475      0.153
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      86/100      3.59G      1.055      1.802     0.6845      1.428          0          3        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.3s
#                    all        115        102      0.679      0.526      0.541      0.203      0.625      0.486       0.47      0.154
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      87/100      3.59G      1.048      1.834     0.6899      1.422          0          9        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.3s
#                    all        115        102      0.522      0.552      0.517      0.204      0.571      0.449      0.455      0.154
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      88/100      3.59G      1.022      1.808     0.6833        1.4          0          8        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.3s
#                    all        115        102      0.706        0.5      0.568      0.207      0.664      0.465      0.483      0.161
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      89/100      3.59G      1.002       1.76     0.6737      1.382          0          5        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1it/s 3.6s
#                    all        115        102      0.653      0.528      0.537      0.201       0.71      0.458      0.468      0.157
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      90/100      3.59G      1.002      1.761     0.6751      1.385          0          7        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.2s
#                    all        115        102      0.671      0.477      0.534      0.191      0.681      0.447      0.465      0.146
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      91/100      3.59G      1.011       1.76      0.663      1.384          0          4        640: 100% ━━━━━━━━━━━━ 57/57 1.4it/s 40.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.0it/s 3.9s
#                    all        115        102      0.558      0.531      0.515      0.197      0.677      0.425      0.456      0.144
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      92/100      3.59G     0.9697      1.739     0.6538      1.357          0          8        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.3s
#                    all        115        102      0.638      0.568      0.532      0.202       0.63      0.537      0.492      0.156
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      93/100      3.59G     0.9675      1.738     0.6492       1.36          0          4        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1it/s 3.8s
#                    all        115        102      0.573      0.497       0.51      0.199      0.568      0.482      0.455       0.15
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      94/100      3.59G     0.9743      1.735     0.6509      1.355          0         10        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.4s
#                    all        115        102      0.681      0.522      0.527      0.196      0.643      0.488       0.47      0.154
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      95/100      3.59G     0.9486      1.699     0.6411      1.345          0          5        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 39.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1it/s 3.6s
#                    all        115        102      0.659      0.506      0.535        0.2      0.698      0.427      0.465      0.152
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      96/100      3.59G     0.9367       1.67     0.6353      1.327          0          6        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.2s
#                    all        115        102      0.625      0.515       0.54      0.202      0.571      0.475      0.463      0.151
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      97/100      3.59G     0.9477      1.705     0.6423      1.329          0         12        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.0it/s 3.8s
#                    all        115        102      0.626      0.537      0.518      0.195      0.581      0.499      0.457      0.151
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      98/100      3.59G     0.9439      1.705     0.6359      1.329          0          8        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.2s
#                    all        115        102      0.648      0.546      0.536      0.204      0.568      0.481      0.459      0.158
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#      99/100      3.59G     0.9273       1.67     0.6318      1.327          0          5        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.0it/s 3.8s
#                    all        115        102      0.637      0.541       0.53      0.202      0.719      0.418      0.467      0.154
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     100/100      3.59G     0.9232      1.647     0.6237      1.317          0          7        640: 100% ━━━━━━━━━━━━ 57/57 1.5it/s 38.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.1s
#                    all        115        102      0.612      0.531      0.531      0.197      0.578      0.499      0.474      0.158
#
# 100 epochs completed in 1.206 hours.
# Optimizer stripped from /content/shrimp_boundary/runs/segment/yolo11n-seg_simam_ca_boundary/weights/last.pt, 6.1MB
# Optimizer stripped from /content/shrimp_boundary/runs/segment/yolo11n-seg_simam_ca_boundary/weights/best.pt, 6.1MB
#
# Validating /content/shrimp_boundary/runs/segment/yolo11n-seg_simam_ca_boundary/weights/best.pt...
# Ultralytics 8.4.67 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11n-seg-simam-ca-boundary summary (fused): 132 layers, 2,846,678 parameters, 0 gradients, 9.6 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.5s/it 6.0s
#                    all        115        102      0.572      0.484      0.518      0.207      0.698      0.457      0.485      0.161
#                     BG         42         46      0.542      0.326      0.409      0.187      0.699      0.253      0.326      0.117
#                   WSSV         53         56      0.601      0.643      0.626      0.227      0.696      0.661      0.644      0.204
# Speed: 0.2ms preprocess, 3.4ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to /content/shrimp_boundary/runs/segment/yolo11n-seg_simam_ca_boundary
# Training finished in 72.8 min.

# %%
# ── Evaluation ─────────────────────────────────────────────────────────────
run_path   = RUNS_DIR / run_name
best_path  = run_path / 'weights' / 'best.pt'
best_model = YOLO(str(best_path))

full_val       = best_model.val(data=str(exp_yaml),          split='val',  imgsz=TRAIN_IMGSZ, plots=True,  verbose=False)
full_test      = best_model.val(data=str(exp_yaml),          split='test', imgsz=TRAIN_IMGSZ, plots=True,  verbose=False)
labeled_val    = best_model.val(data=str(labeled_eval_yaml), split='val',  imgsz=TRAIN_IMGSZ, plots=False, verbose=False)
labeled_test   = best_model.val(data=str(labeled_eval_yaml), split='test', imgsz=TRAIN_IMGSZ, plots=False, verbose=False)

labeled_test_count = count_prediction_errors(
    best_model, labeled_eval_dir/'test'/'images', labeled_eval_dir/'test'/'labels')
healthy_test_fp    = healthy_false_positive_summary(
    best_model, healthy_eval_dir/'test'/'images')

labeled_test_map50 = metric_value(labeled_test, 'seg.map50')
h_score = healthy_aware_score(labeled_test_map50, labeled_test_count, healthy_test_fp)

row = dict(
    experiment=exp_key,
    loss_variant='BCE + BoundaryIoU (weight=0.5)',
    train_time_min=round(train_time_min, 2),
    full_val_mask_map50=metric_value(full_val, 'seg.map50'),
    full_test_mask_map50=metric_value(full_test, 'seg.map50'),
    labeled_val_mask_map50=metric_value(labeled_val, 'seg.map50'),
    labeled_test_mask_map50=labeled_test_map50,
    labeled_test_mask_map50_95=metric_value(labeled_test, 'seg.map'),
    healthy_test_mask_fp_rate=healthy_test_fp['healthy_mask_fp_rate'],
    healthy_aware_score=h_score,
    **labeled_test_count,
)
row.update(read_best_epoch_from_results(run_path))

results_df = pd.DataFrame([row])
results_df.to_csv(REPORT_DIR / 'boundary_loss_results.csv', index=False)
display(results_df.T)

del best_model; gc.collect()
if torch.cuda.is_available(): torch.cuda.empty_cache()
# Out:
# Ultralytics 8.4.67 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11n-seg-simam-ca-boundary summary (fused): 132 layers, 2,846,678 parameters, 0 gradients, 9.6 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3044.5±362.8 MB/s, size: 312.5 KB)
# val: Scanning /content/shrimp_boundary/simam_ca_boundary/dataset/valid/labels.cache... 115 images, 41 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 115/115 18.6Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 1.4it/s 5.8s
#                    all        115        102       0.57      0.484      0.519      0.211      0.698      0.457      0.483      0.162
# Speed: 9.0ms preprocess, 11.5ms inference, 0.0ms loss, 8.7ms postprocess per image
# Results saved to /content/runs/segment/val
# Ultralytics 8.4.67 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1935.2±228.1 MB/s, size: 188.4 KB)
# val: Scanning /content/shrimp_boundary/simam_ca_boundary/dataset/test/labels... 129 images, 41 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 129/129 2.2Kit/s 0.1s
# val: New cache created: /content/shrimp_boundary/simam_ca_boundary/dataset/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 1.3it/s 7.2s
#                    all        129        119      0.585      0.546      0.496       0.19      0.577      0.484      0.422      0.136
# Speed: 7.0ms preprocess, 9.8ms inference, 0.0ms loss, 7.3ms postprocess per image
# Results saved to /content/runs/segment/val-2
# Ultralytics 8.4.67 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2004.7±598.3 MB/s, size: 291.9 KB)
# val: Scanning /content/shrimp_boundary/simam_ca_boundary/dataset_labeled_only_eval/valid/labels... 74 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 74/74 1.9Kit/s 0.0s
# val: New cache created: /content/shrimp_boundary/simam_ca_boundary/dataset_labeled_only_eval/valid/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.6it/s 3.1s
#                    all         74        102       0.59      0.484      0.528      0.213      0.727      0.459      0.489      0.163
# Speed: 2.9ms preprocess, 10.7ms inference, 0.0ms loss, 5.1ms postprocess per image
# Ultralytics 8.4.67 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2017.7±213.5 MB/s, size: 422.7 KB)
# val: Scanning /content/shrimp_boundary/simam_ca_boundary/dataset_labeled_only_eval/test/labels... 88 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 88/88 1.8Kit/s 0.1s
# val: New cache created: /content/shrimp_boundary/simam_ca_boundary/dataset_labeled_only_eval/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.2it/s 2.8s
#                    all         88        119      0.663      0.546      0.552      0.213      0.653      0.485       0.47      0.153
# Speed: 1.8ms preprocess, 7.7ms inference, 0.0ms loss, 2.7ms postprocess per image
#                                                            0
# experiment                                 simam_ca_boundary
# loss_variant                  BCE + BoundaryIoU (weight=0.5)
# train_time_min                                         72.75
# full_val_mask_map50                                 0.483366
# full_test_mask_map50                                0.421516
# labeled_val_mask_map50                              0.489251
# labeled_test_mask_map50                             0.469855
# labeled_test_mask_map50_95                          0.152853
# healthy_test_mask_fp_rate                           0.317073
# healthy_aware_score                                  0.39222
# images                                                    88
# gt_total                                                 119
# pred_mask_total                                          111
# mask_count_mae                                      0.441288
# disease_images                                            88
# disease_box_miss_rate                               0.159091
# disease_mask_miss_rate                                   NaN
# epochs_ran                                               100
# best_epoch_by_mask_map50                                  92
# best_val_mask_map50                                   0.4918
# last_train_seg_loss                                  1.64655
# last_val_seg_loss                                    4.82947
# seg_loss_gap_val_minus_train                         3.18292

# %%
import matplotlib.pyplot as plt, matplotlib.image as mpimg
results_png = run_path / 'results.png'
if results_png.exists():
    plt.figure(figsize=(14, 10))
    plt.imshow(mpimg.imread(results_png))
    plt.axis('off')
    plt.title('Boundary-Aware Mask Loss Training Curves')
    plt.show()
