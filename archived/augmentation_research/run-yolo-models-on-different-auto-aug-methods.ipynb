# %% [markdown]
# # Shrimp Disease YOLO Auto-Augmentation Benchmark
#
# Trains the original YOLO classification variants with TrivialAugmentWide, RandAugment, and AugMix. RandAugment and AugMix use Ultralytics' built-in classification `auto_augment` modes. TrivialAugmentWide is implemented as a small custom PIL-based policy and used to create one offline augmented replacement for each original training image. Validation and test splits remain unaugmented.

# %%
print("Running Kaggle YOLO auto-augmentation benchmark. Input data is read from /kaggle/input; outputs are written to /kaggle/working.")
# Out:
# Running Kaggle YOLO auto-augmentation benchmark. Input data is read from /kaggle/input; outputs are written to /kaggle/working.

# %% [markdown]
# ## 1. Install Dependencies

# %%
import importlib.util
import subprocess
import sys

packages = [
    "ultralytics>=8.3.0",
]


def import_name_for(package_spec: str) -> str:
    package = package_spec.split(">=")[0].split("==")[0].split("<")[0]
    return {"ultralytics": "ultralytics"}.get(package, package.replace("-", "_"))


missing = [pkg for pkg in packages if importlib.util.find_spec(import_name_for(pkg)) is None]
if missing:
    print("Installing missing dependencies:", missing)
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "-U", *missing])
else:
    print("All training dependencies are already available.")
# Out:
# Installing missing dependencies: ['ultralytics>=8.3.0']
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 21.8 MB/s eta 0:00:00

# %% [markdown]
# ## 2. Configuration and Fixed Split

# %%
import gc
import random
import shutil
import subprocess
import time
from pathlib import Path

import numpy as np
import pandas as pd
import torch
from PIL import Image, ImageEnhance, ImageOps
from sklearn.metrics import accuracy_score, cohen_kappa_score, f1_score
from sklearn.model_selection import train_test_split
from tqdm.auto import tqdm
from ultralytics import YOLO

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True
torch.use_deterministic_algorithms(True, warn_only=True)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

IMG_SIZE = 224
EPOCHS = 30
PATIENCE = 15
YOLO_BATCH_SIZE = 32
ENABLE_GPU_LOGGING = True
GPU_LOG_EVERY_N_EPOCHS = 1

DATA_DIR = Path("/kaggle/input/datasets/uynnhy/processed-images/processed_images")
OUTPUT_DIR = Path("/kaggle/working/yolo_autoaugment_model_comparison")
YOLO_DATA_ROOT = OUTPUT_DIR / "yolo_datasets"
YOLO_RUNS_DIR = OUTPUT_DIR / "yolo_runs"
REPORT_DIR = OUTPUT_DIR / "reports"

for directory in [YOLO_DATA_ROOT, YOLO_RUNS_DIR, REPORT_DIR]:
    directory.mkdir(parents=True, exist_ok=True)

CLASS_DIRS = ["1. Healthy", "2. BG", "3. WSSV", "4. WSSV_BG"]
CLASS_NAMES = ["Healthy", "BG", "WSSV", "WSSV_BG"]
CLASS_TO_IDX = {folder: idx for idx, folder in enumerate(CLASS_DIRS)}
NUM_CLASSES = len(CLASS_DIRS)

YOLO_MODELS = ["yolo26n-cls", "yolo26m-cls", "yolo11n-cls", "yolo11m-cls"]
ALL_MODELS = YOLO_MODELS.copy()

AUTO_AUGMENT_POLICIES = {
    "trivial_aug": "TrivialAugmentWide",
    "randaug": "RandAugment",
    "augmix": "AugMix",
}

YOLO_AUTO_AUGMENT_BY_POLICY = {
    "trivial_aug": None,
    "randaug": "randaugment",
    "augmix": "augmix",
}


def reset_random_state(seed: int = SEED):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


def sanitize_name(name: str) -> str:
    return name.replace("/", "_").replace(" ", "_").replace(".", "_")


def count_params(model) -> float:
    return sum(param.numel() for param in model.parameters()) / 1e6


def gpu_status_text() -> str:
    if not torch.cuda.is_available():
        return "CUDA unavailable"

    allocated = torch.cuda.memory_allocated() / 1024**2
    reserved = torch.cuda.memory_reserved() / 1024**2
    max_allocated = torch.cuda.max_memory_allocated() / 1024**2
    text = f"torch CUDA memory allocated/reserved/max: {allocated:.1f}/{reserved:.1f}/{max_allocated:.1f} MB"

    try:
        completed = subprocess.run(
            [
                "nvidia-smi",
                "--query-gpu=utilization.gpu,memory.used,memory.total,power.draw,temperature.gpu",
                "--format=csv,noheader,nounits",
            ],
            capture_output=True,
            text=True,
            timeout=5,
        )
        if completed.returncode == 0:
            first_gpu = completed.stdout.strip().splitlines()[0]
            util, mem_used, mem_total, power, temp = [part.strip() for part in first_gpu.split(",")[:5]]
            text += f" | nvidia-smi util={util}% mem={mem_used}/{mem_total} MB power={power} W temp={temp} C"
        else:
            text += f" | nvidia-smi failed: {completed.stderr.strip()[-200:]}"
    except Exception as exc:
        text += f" | nvidia-smi unavailable: {type(exc).__name__}: {exc}"

    return text


def print_gpu_status(label: str):
    if ENABLE_GPU_LOGGING:
        print(f"[GPU] {label}: {gpu_status_text()}")


print_gpu_status("startup")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Using device: cuda
# [GPU] startup: torch CUDA memory allocated/reserved/max: 0.0/0.0/0.0 MB | nvidia-smi util=0% mem=3/15360 MB power=9.66 W temp=36 C

# %%
def discover_processed_images(data_dir: Path) -> pd.DataFrame:
    rows = []
    for class_dir in CLASS_DIRS:
        folder = data_dir / class_dir
        if not folder.exists():
            print(f"Warning: missing class folder: {folder}")
            continue
        for path in sorted(folder.iterdir()):
            if path.suffix.lower() in {".jpg", ".jpeg", ".png", ".bmp", ".webp"}:
                rows.append({"path": str(path), "class_dir": class_dir, "label": CLASS_TO_IDX[class_dir]})
    frame = pd.DataFrame(rows)
    if frame.empty:
        raise RuntimeError(f"No images found under {data_dir}. Run preprocessing from the baseline first.")
    return frame


df = discover_processed_images(DATA_DIR)
print(f"Loaded {len(df)} processed images from {DATA_DIR}")
display(df["class_dir"].value_counts().reindex(CLASS_DIRS).rename("count").to_frame())

train_df, tmp_df = train_test_split(
    df,
    test_size=0.30,
    stratify=df["label"],
    random_state=SEED,
    shuffle=True,
)
val_df, test_df = train_test_split(
    tmp_df,
    test_size=0.50,
    stratify=tmp_df["label"],
    random_state=SEED,
    shuffle=True,
)

for split_name, split_df in [("train", train_df), ("val", val_df), ("test", test_df)]:
    print(f"{split_name}: {len(split_df)} images")
    print(split_df["class_dir"].value_counts().reindex(CLASS_DIRS).to_dict())

assert set(train_df["path"]).isdisjoint(set(val_df["path"]))
assert set(train_df["path"]).isdisjoint(set(test_df["path"]))
assert set(val_df["path"]).isdisjoint(set(test_df["path"]))
print("Image-level split overlap check passed.")
# Out:
# Loaded 1149 processed images from /kaggle/input/datasets/uynnhy/processed-images/processed_images
#             count
# class_dir
# 1. Healthy    403
# 2. BG         198
# 3. WSSV       328
# 4. WSSV_BG    220
# train: 804 images
# {'1. Healthy': 282, '2. BG': 139, '3. WSSV': 229, '4. WSSV_BG': 154}
# val: 172 images
# {'1. Healthy': 60, '2. BG': 30, '3. WSSV': 49, '4. WSSV_BG': 33}
# test: 173 images
# {'1. Healthy': 61, '2. BG': 29, '3. WSSV': 50, '4. WSSV_BG': 33}
# Image-level split overlap check passed.

# %% [markdown]
# ## 3. YOLO Datasets and Custom TrivialAugmentWide
#
# RandAugment and AugMix use the original training split with Ultralytics built-in `auto_augment`. TrivialAugmentWide uses one custom offline augmented replacement per training image.

# %%
TRIVIAL_AUGMENT_BINS = 31
TRIVIAL_AUGMENT_OPS = [
    "identity",
    "autocontrast",
    "equalize",
    "rotate",
    "solarize",
    "color",
    "contrast",
    "brightness",
    "sharpness",
    "shear_x",
    "shear_y",
    "translate_x",
    "translate_y",
]


def magnitude_value(max_value: float, signed: bool = False):
    magnitude = random.randint(0, TRIVIAL_AUGMENT_BINS - 1) / (TRIVIAL_AUGMENT_BINS - 1)
    value = magnitude * max_value
    if signed and random.random() < 0.5:
        value *= -1
    return value


def apply_custom_trivial_augment(image: Image.Image) -> Image.Image:
    op = random.choice(TRIVIAL_AUGMENT_OPS)
    if op == "identity":
        return image
    if op == "autocontrast":
        return ImageOps.autocontrast(image)
    if op == "equalize":
        return ImageOps.equalize(image)
    if op == "rotate":
        degrees = magnitude_value(30.0, signed=True)
        return image.rotate(degrees, resample=Image.Resampling.BILINEAR, fillcolor=(128, 128, 128))
    if op == "solarize":
        threshold = int(256 - magnitude_value(256.0))
        return ImageOps.solarize(image, threshold=max(0, min(256, threshold)))
    if op == "color":
        factor = 1.0 + magnitude_value(0.9, signed=True)
        return ImageEnhance.Color(image).enhance(max(0.1, factor))
    if op == "contrast":
        factor = 1.0 + magnitude_value(0.9, signed=True)
        return ImageEnhance.Contrast(image).enhance(max(0.1, factor))
    if op == "brightness":
        factor = 1.0 + magnitude_value(0.9, signed=True)
        return ImageEnhance.Brightness(image).enhance(max(0.1, factor))
    if op == "sharpness":
        factor = 1.0 + magnitude_value(0.9, signed=True)
        return ImageEnhance.Sharpness(image).enhance(max(0.1, factor))
    if op == "shear_x":
        shear = magnitude_value(0.3, signed=True)
        return image.transform(image.size, Image.Transform.AFFINE, (1, shear, 0, 0, 1, 0), resample=Image.Resampling.BILINEAR, fillcolor=(128, 128, 128))
    if op == "shear_y":
        shear = magnitude_value(0.3, signed=True)
        return image.transform(image.size, Image.Transform.AFFINE, (1, 0, 0, shear, 1, 0), resample=Image.Resampling.BILINEAR, fillcolor=(128, 128, 128))
    if op == "translate_x":
        offset = int(round(magnitude_value(0.45, signed=True) * image.size[0]))
        return image.transform(image.size, Image.Transform.AFFINE, (1, 0, offset, 0, 1, 0), resample=Image.Resampling.BILINEAR, fillcolor=(128, 128, 128))
    if op == "translate_y":
        offset = int(round(magnitude_value(0.45, signed=True) * image.size[1]))
        return image.transform(image.size, Image.Transform.AFFINE, (1, 0, 0, 0, 1, offset), resample=Image.Resampling.BILINEAR, fillcolor=(128, 128, 128))
    raise ValueError(f"Unsupported TrivialAugment op: {op}")


def resize_crop_for_yolo(image: Image.Image) -> Image.Image:
    width, height = image.size
    scale = random.uniform(0.82, 1.0)
    aspect = random.uniform(0.90, 1.10)
    crop_area = width * height * scale
    crop_w = int(round((crop_area * aspect) ** 0.5))
    crop_h = int(round((crop_area / aspect) ** 0.5))
    crop_w = min(width, max(1, crop_w))
    crop_h = min(height, max(1, crop_h))
    left = random.randint(0, max(0, width - crop_w))
    top = random.randint(0, max(0, height - crop_h))
    image = image.crop((left, top, left + crop_w, top + crop_h))
    return image.resize((IMG_SIZE, IMG_SIZE), Image.Resampling.BICUBIC)


def apply_trivial_aug_train_transform(image: Image.Image) -> Image.Image:
    return apply_custom_trivial_augment(resize_crop_for_yolo(image))


def save_image_for_yolo(image: Image.Image, dst: Path):
    image.convert("RGB").save(dst, quality=95)


def unique_image_name(src: Path, row_idx: int, suffix: str = ".jpg") -> str:
    return f"{src.stem}_{row_idx:06d}{suffix}"


def prepare_yolo_dataset_for_augmentation(augmentation_key: str) -> Path:
    augmentation_name = AUTO_AUGMENT_POLICIES[augmentation_key]
    dataset_dir = YOLO_DATA_ROOT / augmentation_key
    if dataset_dir.exists():
        shutil.rmtree(dataset_dir)

    for split_name in ["train", "val", "test"]:
        for class_dir in CLASS_DIRS:
            (dataset_dir / split_name / class_dir).mkdir(parents=True, exist_ok=True)

    reset_random_state(SEED)
    if augmentation_key == "trivial_aug":
        print(f"Creating custom offline {augmentation_name} training split at {dataset_dir / 'train'}")
    else:
        print(f"Copying original training split for built-in YOLO {augmentation_name} at {dataset_dir / 'train'}")

    for row_idx, (_, row) in enumerate(tqdm(train_df.iterrows(), total=len(train_df), desc=f"Build {augmentation_name} train")):
        src = Path(row["path"])
        if augmentation_key == "trivial_aug":
            dst = dataset_dir / "train" / row["class_dir"] / unique_image_name(src, row_idx)
            image = Image.open(src).convert("RGB")
            save_image_for_yolo(apply_trivial_aug_train_transform(image), dst)
        else:
            dst = dataset_dir / "train" / row["class_dir"] / unique_image_name(src, row_idx, src.suffix.lower() or ".jpg")
            shutil.copy2(src, dst)

    for split_name, split_df in [("val", val_df), ("test", test_df)]:
        for row_idx, (_, row) in enumerate(tqdm(split_df.iterrows(), total=len(split_df), desc=f"Copy {split_name}")):
            src = Path(row["path"])
            dst = dataset_dir / split_name / row["class_dir"] / unique_image_name(src, row_idx, src.suffix.lower() or ".jpg")
            shutil.copy2(src, dst)

    print(f"Prepared YOLO dataset for {augmentation_name}: {dataset_dir}")
    return dataset_dir

# %% [markdown]
# ## 4. YOLO Training and Evaluation

# %%
def yolo_device_arg():
    return 0 if torch.cuda.is_available() else "cpu"


def evaluate_yolo_model(yolo_model, eval_df: pd.DataFrame, timed=False):
    names = yolo_model.names
    name_to_idx = {value: int(key) for key, value in names.items()}
    source_paths = eval_df["path"].tolist()

    if timed:
        _ = yolo_model.predict(source=source_paths[:1], imgsz=IMG_SIZE, device=yolo_device_arg(), verbose=False)
        if torch.cuda.is_available():
            torch.cuda.synchronize()
        start = time.time()
    else:
        start = None

    preds = yolo_model.predict(
        source=source_paths,
        imgsz=IMG_SIZE,
        batch=YOLO_BATCH_SIZE,
        device=yolo_device_arg(),
        verbose=False,
    )

    if timed and torch.cuda.is_available():
        torch.cuda.synchronize()
    elapsed = time.time() - start if timed else None

    y_true = [name_to_idx[class_dir] for class_dir in eval_df["class_dir"].tolist()]
    y_pred = [int(result.probs.top1) for result in preds]

    return {
        "accuracy": accuracy_score(y_true, y_pred),
        "macro_f1": f1_score(y_true, y_pred, average="macro", zero_division=0),
        "cohen_kappa": cohen_kappa_score(y_true, y_pred),
        "elapsed": elapsed,
        "labels": y_true,
        "preds": y_pred,
    }


YOLO_AUGMENTATION_BASE_ARGS = {
    "hsv_h": 0.0,
    "hsv_s": 0.0,
    "hsv_v": 0.0,
    "degrees": 0.0,
    "translate": 0.0,
    "scale": 0.0,
    "shear": 0.0,
    "perspective": 0.0,
    "flipud": 0.0,
    "fliplr": 0.0,
    "mosaic": 0.0,
    "mixup": 0.0,
    "cutmix": 0.0,
    "copy_paste": 0.0,
    "erasing": 0.0,
    "crop_fraction": 1.0,
}


def yolo_augmentation_args(augmentation_key: str) -> dict:
    args = YOLO_AUGMENTATION_BASE_ARGS.copy()
    args["auto_augment"] = YOLO_AUTO_AUGMENT_BY_POLICY[augmentation_key]
    return args


def train_yolo_model(model_name: str, augmentation_key: str, dataset_dir: Path) -> dict:
    augmentation_name = AUTO_AUGMENT_POLICIES[augmentation_key]
    print("\n" + "=" * 90)
    print(f"Training YOLO classifier: {model_name} | Augmentation: {augmentation_name}")
    print("=" * 90)

    weights_name = f"{model_name}.pt"
    run_name = f"{augmentation_key}_{sanitize_name(model_name)}"
    train_start = time.time()
    yolo = YOLO(weights_name)
    print_gpu_status(f"{augmentation_name} / {model_name} before YOLO train")
    yolo.train(
        data=str(dataset_dir),
        task="classify",
        imgsz=IMG_SIZE,
        epochs=EPOCHS,
        batch=YOLO_BATCH_SIZE,
        patience=PATIENCE,
        seed=SEED,
        project=str(YOLO_RUNS_DIR),
        name=run_name,
        exist_ok=True,
        device=yolo_device_arg(),
        verbose=True,
        **yolo_augmentation_args(augmentation_key),
    )
    print_gpu_status(f"{augmentation_name} / {model_name} after YOLO train")
    train_time = time.time() - train_start

    best_path = YOLO_RUNS_DIR / run_name / "weights" / "best.pt"
    if not best_path.exists():
        candidates = sorted((YOLO_RUNS_DIR / run_name).glob("**/best.pt"))
        if not candidates:
            raise FileNotFoundError(f"Could not locate YOLO best checkpoint for {model_name} / {augmentation_name}")
        best_path = candidates[-1]

    best_yolo = YOLO(str(best_path))
    print_gpu_status(f"{augmentation_name} / {model_name} before YOLO eval")
    val_metrics = evaluate_yolo_model(best_yolo, val_df, timed=False)
    test_metrics = evaluate_yolo_model(best_yolo, test_df, timed=True)
    print_gpu_status(f"{augmentation_name} / {model_name} after YOLO eval")
    inf_time = test_metrics["elapsed"]
    params_m = count_params(best_yolo.model)

    result = {
        "Augmentation": augmentation_name,
        "Augmentation Key": augmentation_key,
        "Model": model_name,
        "Backend Name": weights_name,
        "Parameters (M)": round(params_m, 2),
        "Training Time (s)": round(train_time, 1),
        "Val F1-Score": round(val_metrics["macro_f1"], 4),
        "Test Accuracy": round(test_metrics["accuracy"], 4),
        "Test F1-Score": round(test_metrics["macro_f1"], 4),
        "Cohen Kappa": round(test_metrics["cohen_kappa"], 4),
        "Inference Time (s)": round(inf_time, 2),
        "FPS": round(len(test_df) / inf_time, 1),
        "Latency (ms)": round((inf_time / len(test_df)) * 1000, 2),
        "Checkpoint Path": str(best_path),
        "Export Format": "",
        "Export Path": "",
        "Export Note": f"YOLO auto_augment={YOLO_AUTO_AUGMENT_BY_POLICY[augmentation_key]}; other augmentation knobs disabled. TrivialAugmentWide uses custom offline replacement images.",
    }

    del yolo, best_yolo
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
    gc.collect()
    return result

# %% [markdown]
# ## 5. Sequential YOLO Auto-Augmentation Loop
#
# Partial CSV/JSON files are saved after every model.

# %%
comparison_results = []

for augmentation_key, augmentation_name in AUTO_AUGMENT_POLICIES.items():
    print("\n" + "#" * 90)
    print(f"Starting YOLO augmentation benchmark: {augmentation_name}")
    print("#" * 90)
    dataset_dir = prepare_yolo_dataset_for_augmentation(augmentation_key)

    for model_name in ALL_MODELS:
        try:
            reset_random_state(SEED)
            result = train_yolo_model(model_name, augmentation_key, dataset_dir)
            comparison_results.append(result)
            print("Recorded result:")
            display(pd.DataFrame([result]))
        except Exception as exc:
            print(f"ERROR while running {augmentation_name} / {model_name}: {type(exc).__name__}: {exc}")
            comparison_results.append(
                {
                    "Augmentation": augmentation_name,
                    "Augmentation Key": augmentation_key,
                    "Model": model_name,
                    "Backend Name": "",
                    "Parameters (M)": np.nan,
                    "Training Time (s)": np.nan,
                    "Val F1-Score": np.nan,
                    "Test Accuracy": np.nan,
                    "Test F1-Score": np.nan,
                    "Cohen Kappa": np.nan,
                    "Inference Time (s)": np.nan,
                    "FPS": np.nan,
                    "Latency (ms)": np.nan,
                    "Checkpoint Path": "",
                    "Export Format": "not_run",
                    "Export Path": "",
                    "Export Note": f"Run failed: {type(exc).__name__}: {exc}",
                }
            )

        partial_df = pd.DataFrame(comparison_results)
        partial_df.to_csv(REPORT_DIR / "yolo_autoaugment_model_comparison_partial.csv", index=False)
        partial_df.to_json(REPORT_DIR / "yolo_autoaugment_model_comparison_partial.json", orient="records", indent=2)
# Out:
# ##########################################################################################
# Starting YOLO augmentation benchmark: TrivialAugmentWide
# ##########################################################################################
# Creating custom offline TrivialAugmentWide training split at /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/train
# Build TrivialAugmentWide train:   0%|          | 0/804 [00:00<?, ?it/s]
# Copy val:   0%|          | 0/172 [00:00<?, ?it/s]
# Copy test:   0%|          | 0/173 [00:00<?, ?it/s]
# Prepared YOLO dataset for TrivialAugmentWide: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug
#
# ==========================================================================================
# Training YOLO classifier: yolo26n-cls | Augmentation: TrivialAugmentWide
# ==========================================================================================
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n-cls.pt to 'yolo26n-cls.pt': 100% ━━━━━━━━━━━━ 5.5MB 71.2MB/s 0.1s
# [GPU] TrivialAugmentWide / yolo26n-cls before YOLO train: torch CUDA memory allocated/reserved/max: 0.0/0.0/0.0 MB | nvidia-smi util=0% mem=3/15360 MB power=9.37 W temp=36 C
# WARNING ⚠️ 'crop_fraction' is deprecated and will be removed in the future.
# Ultralytics 8.4.53 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=None, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=30, erasing=0.0, exist_ok=True, fliplr=0.0, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.0, hsv_s=0.0, hsv_v=0.0, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n-cls.pt, momentum=0.937, mosaic=0.0, multi_scale=0.0, name=trivial_aug_yolo26n-cls, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/yolo_autoaugment_model_comparison/yolo_runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/yolo_autoaugment_model_comparison/yolo_runs/trivial_aug_yolo26n-cls, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.0, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.0, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/train... found 804 images in 4 classes ✅
# val: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/val... found 172 images in 4 classes ✅
# test: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/test... found 173 images in 4 classes ✅
# Overriding model.yaml nc=1000 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  10                  -1  1    335364  ultralytics.nn.modules.head.Classify         [256, 4]
# YOLO26n-cls summary: 86 layers, 1,536,228 parameters, 1,536,228 gradients, 3.3 GFLOPs
# Transferred 234/236 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 62.8MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 232.1±77.9 MB/s, size: 7.8 KB)
# train: Scanning /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/train... 804 images, 0 corrupt: 100% ━━━━━━━━━━━━ 804/804 2.6Kit/s 0.3s0.0ss
# train: New cache created: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2188.7±1490.7 MB/s, size: 922.1 KB)
# val: Scanning /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/val... 172 images, 0 corrupt: 100% ━━━━━━━━━━━━ 172/172 397.3it/s 0.4s0.0s
# val: New cache created: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/yolo_autoaugment_model_comparison/yolo_runs/trivial_aug_yolo26n-cls
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 15.0MB/s 0.0s
#        1/30     0.447G      1.293          4        224: 100% ━━━━━━━━━━━━ 26/26 2.5it/s 10.4s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.0s/it 6.1s<34.3s
#                    all      0.599          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/30     0.547G     0.7956          4        224: 100% ━━━━━━━━━━━━ 26/26 7.8it/s 3.3s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.6s/it 4.9s8.2s
#                    all      0.669          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/30     0.551G      0.436          4        224: 100% ━━━━━━━━━━━━ 26/26 8.2it/s 3.2s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.6s/it 4.9s
#                    all      0.407          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/30     0.551G     0.2965          4        224: 100% ━━━━━━━━━━━━ 26/26 7.8it/s 3.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 45.3it/s 0.1s
#                    all      0.395          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/30     0.551G     0.2502          4        224: 100% ━━━━━━━━━━━━ 26/26 7.8it/s 3.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.0s/it 6.0s1.8s3s
#                    all      0.552          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/30     0.551G     0.2428          4        224: 100% ━━━━━━━━━━━━ 26/26 9.1it/s 2.9s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.6s/it 7.7s<12.8s
#                    all      0.669          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/30     0.551G     0.2898          4        224: 100% ━━━━━━━━━━━━ 26/26 9.2it/s 2.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.5s/it 4.4s
#                    all      0.599          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/30     0.551G     0.1563          4        224: 100% ━━━━━━━━━━━━ 26/26 8.5it/s 3.1s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 31.2it/s 0.1s
#                    all      0.657          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/30     0.551G     0.1264          4        224: 100% ━━━━━━━━━━━━ 26/26 8.1it/s 3.2s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.0s/it 5.9s1.7s8s
#                    all      0.552          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/30     0.551G     0.1275          4        224: 100% ━━━━━━━━━━━━ 26/26 9.5it/s 2.7s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.4s/it 7.3s<12.0s
#                    all      0.616          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/30     0.551G    0.06247          4        224: 100% ━━━━━━━━━━━━ 26/26 9.2it/s 2.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.5s/it 4.5s
#                    all      0.669          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/30     0.551G    0.02919          4        224: 100% ━━━━━━━━━━━━ 26/26 9.1it/s 2.9s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 30.9it/s 0.1s
#                    all      0.698          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/30     0.551G    0.02342          4        224: 100% ━━━━━━━━━━━━ 26/26 9.9it/s 2.6s0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.3s/it 7.0s1.9s5s
#                    all      0.645          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/30     0.551G    0.04276          4        224: 100% ━━━━━━━━━━━━ 26/26 9.2it/s 2.8s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.4s/it 7.2s<11.9s
#                    all       0.61          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/30     0.551G    0.02226          4        224: 100% ━━━━━━━━━━━━ 26/26 9.0it/s 2.9s0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.6s/it 4.8s
#                    all       0.61          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/30     0.551G    0.05604          4        224: 100% ━━━━━━━━━━━━ 26/26 9.0it/s 2.9s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 57.4it/s 0.1s
#                    all      0.581          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/30     0.551G    0.01805          4        224: 100% ━━━━━━━━━━━━ 26/26 8.5it/s 3.1s0.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.2s/it 6.6s1.1s4s
#                    all      0.669          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/30     0.551G    0.00897          4        224: 100% ━━━━━━━━━━━━ 26/26 8.7it/s 3.0s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.6s/it 7.7s<12.7s
#                    all       0.68          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/30     0.551G   0.003337          4        224: 100% ━━━━━━━━━━━━ 26/26 8.0it/s 3.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.5s/it 4.6s
#                    all       0.68          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/30     0.551G   0.001747          4        224: 100% ━━━━━━━━━━━━ 26/26 8.5it/s 3.1s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 43.9it/s 0.1s
#                    all       0.68          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/30     0.551G   0.002275          4        224: 100% ━━━━━━━━━━━━ 26/26 7.8it/s 3.3s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.4s/it 7.2s4.3s6s
#                    all      0.674          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/30     0.551G   0.009202          4        224: 100% ━━━━━━━━━━━━ 26/26 9.2it/s 2.8s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.3s/it 6.8s<11.3s
#                    all      0.674          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/30     0.551G   0.002456          4        224: 100% ━━━━━━━━━━━━ 26/26 9.3it/s 2.8s0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.7s/it 5.0s
#                    all      0.663          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/30     0.551G    0.01193          4        224: 100% ━━━━━━━━━━━━ 26/26 8.7it/s 3.0s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 46.1it/s 0.1s
#                    all      0.674          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/30     0.551G   0.004257          4        224: 100% ━━━━━━━━━━━━ 26/26 9.5it/s 2.7s0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.6s/it 7.9s5.0s7s
#                    all      0.686          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       26/30     0.551G   0.006999          4        224: 100% ━━━━━━━━━━━━ 26/26 9.4it/s 2.8s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.1s/it 6.3s<10.5s
#                    all      0.692          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       27/30     0.551G   0.000802          4        224: 100% ━━━━━━━━━━━━ 26/26 8.4it/s 3.1s0.1ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.5s/it 4.6s
#                    all      0.692          1
# EarlyStopping: Training stopped early as no improvement observed in last 15 epochs. Best results observed at epoch 12, best model saved as best.pt.
# To update EarlyStopping(patience=15) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 27 epochs completed in 0.063 hours.
# Optimizer stripped from /kaggle/working/yolo_autoaugment_model_comparison/yolo_runs/trivial_aug_yolo26n-cls/weights/last.pt, 3.2MB
# Optimizer stripped from /kaggle/working/yolo_autoaugment_model_comparison/yolo_runs/trivial_aug_yolo26n-cls/weights/best.pt, 3.2MB
#
# Validating /kaggle/working/yolo_autoaugment_model_comparison/yolo_runs/trivial_aug_yolo26n-cls/weights/best.pt...
# Ultralytics 8.4.53 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26n-cls summary (fused): 47 layers, 1,531,148 parameters, 0 gradients, 3.2 GFLOPs
# train: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/train... found 804 images in 4 classes ✅
# val: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/val... found 172 images in 4 classes ✅
# test: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/test... found 173 images in 4 classes ✅
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 3.6it/s 0.8s4.9s
#                    all      0.698          1
# Speed: 0.1ms preprocess, 0.4ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /kaggle/working/yolo_autoaugment_model_comparison/yolo_runs/trivial_aug_yolo26n-cls
# [GPU] TrivialAugmentWide / yolo26n-cls after YOLO train: torch CUDA memory allocated/reserved/max: 89.8/170.0/429.9 MB | nvidia-smi util=9% mem=371/15360 MB power=28.54 W temp=56 C
# [GPU] TrivialAugmentWide / yolo26n-cls before YOLO eval: torch CUDA memory allocated/reserved/max: 89.8/170.0/429.9 MB | nvidia-smi util=0% mem=371/15360 MB power=28.54 W temp=56 C
# [GPU] TrivialAugmentWide / yolo26n-cls after YOLO eval: torch CUDA memory allocated/reserved/max: 95.8/834.0/593.1 MB | nvidia-smi util=6% mem=1037/15360 MB power=42.07 W temp=58 C
# Recorded result:
#          Augmentation Augmentation Key        Model    Backend Name  \
# 0  TrivialAugmentWide      trivial_aug  yolo26n-cls  yolo26n-cls.pt
#
#    Parameters (M)  Training Time (s)  Val F1-Score  Test Accuracy  \
# 0            1.53              244.3        0.6621          0.659
#
#    Test F1-Score  Cohen Kappa  Inference Time (s)  FPS  Latency (ms)  \
# 0         0.6074       0.5228                27.5  6.3        158.95
#
#                                      Checkpoint Path Export Format  \
# 0  /kaggle/working/yolo_autoaugment_model_compari...
#
#   Export Path                                        Export Note
# 0              YOLO auto_augment=None; other augmentation kno...
# ==========================================================================================
# Training YOLO classifier: yolo26m-cls | Augmentation: TrivialAugmentWide
# ==========================================================================================
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26m-cls.pt to 'yolo26m-cls.pt': 100% ━━━━━━━━━━━━ 22.4MB 120.1MB/s 0.2s1s<0.2s
# [GPU] TrivialAugmentWide / yolo26m-cls before YOLO train: torch CUDA memory allocated/reserved/max: 65.0/168.0/593.1 MB | nvidia-smi util=0% mem=371/15360 MB power=28.93 W temp=58 C
# WARNING ⚠️ 'crop_fraction' is deprecated and will be removed in the future.
# Ultralytics 8.4.53 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=None, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=30, erasing=0.0, exist_ok=True, fliplr=0.0, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.0, hsv_s=0.0, hsv_v=0.0, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26m-cls.pt, momentum=0.937, mosaic=0.0, multi_scale=0.0, name=trivial_aug_yolo26m-cls, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/yolo_autoaugment_model_comparison/yolo_runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/yolo_autoaugment_model_comparison/yolo_runs/trivial_aug_yolo26m-cls, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.0, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.0, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/train... found 804 images in 4 classes ✅
# val: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/val... found 172 images in 4 classes ✅
# test: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/test... found 173 images in 4 classes ✅
# Overriding model.yaml nc=1000 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  10                  -1  1    663044  ultralytics.nn.modules.head.Classify         [512, 4]
# YOLO26m-cls summary: 106 layers, 10,358,340 parameters, 10,358,340 gradients, 39.6 GFLOPs
# Transferred 294/296 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 296.8±79.0 MB/s, size: 7.8 KB)
# train: Scanning /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/train... 804 images, 0 corrupt: 100% ━━━━━━━━━━━━ 804/804 374.7Mit/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1988.2±1806.9 MB/s, size: 922.1 KB)
# val: Scanning /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/val... 172 images, 0 corrupt: 100% ━━━━━━━━━━━━ 172/172 8.4Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 49 weight(decay=0.0), 50 weight(decay=0.0005), 50 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/yolo_autoaugment_model_comparison/yolo_runs/trivial_aug_yolo26m-cls
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/30      1.44G      1.258          4        224: 100% ━━━━━━━━━━━━ 26/26 2.6it/s 10.0s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.7s/it 5.0s<27.1s
#                    all      0.616          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/30      1.79G     0.6607          4        224: 100% ━━━━━━━━━━━━ 26/26 5.9it/s 4.4s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.5s/it 4.5s7.5s
#                    all      0.564          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/30      1.79G     0.3004          4        224: 100% ━━━━━━━━━━━━ 26/26 7.5it/s 3.5s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.3s/it 3.9s0.2s
#                    all      0.663          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/30      1.79G     0.2683          4        224: 100% ━━━━━━━━━━━━ 26/26 6.5it/s 4.0s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 20.7it/s 0.1s.2s
#                    all      0.535          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/30      1.79G     0.5218          4        224: 100% ━━━━━━━━━━━━ 26/26 7.4it/s 3.5s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.5s/it 4.5s0.6s2s
#                    all       0.64          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/30      1.79G     0.3467          4        224: 100% ━━━━━━━━━━━━ 26/26 6.6it/s 3.9s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.2s/it 6.5s<10.7s
#                    all      0.674          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/30      1.79G     0.2574          4        224: 100% ━━━━━━━━━━━━ 26/26 7.4it/s 3.5s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.2s/it 3.7s
#                    all      0.686          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/30      1.79G      0.215          4        224: 100% ━━━━━━━━━━━━ 26/26 7.2it/s 3.6s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 20.5it/s 0.1s.2s
#                    all      0.535          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/30      1.79G     0.1979          4        224: 100% ━━━━━━━━━━━━ 26/26 7.8it/s 3.4s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.6s/it 4.9s<31.9s
#                    all      0.576          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/30      1.79G      0.154          4        224: 100% ━━━━━━━━━━━━ 26/26 7.0it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.3s/it 7.0s<11.6s
#                    all      0.651          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/30      1.79G    0.04866          4        224: 100% ━━━━━━━━━━━━ 26/26 6.7it/s 3.9s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.3s/it 3.9s0.2s
#                    all      0.698          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/30      1.79G    0.07903          4        224: 100% ━━━━━━━━━━━━ 26/26 6.7it/s 3.9s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 21.2it/s 0.1s.2s
#                    all       0.68          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/30      1.79G    0.06943          4        224: 100% ━━━━━━━━━━━━ 26/26 6.9it/s 3.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.3s/it 4.0s<26.0s
#                    all      0.669          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/30      1.79G    0.03372          4        224: 100% ━━━━━━━━━━━━ 26/26 7.1it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.2s/it 6.5s<10.8s
#                    all      0.703          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/30      1.79G    0.04458          4        224: 100% ━━━━━━━━━━━━ 26/26 7.2it/s 3.6s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.2s/it 3.6s0.2s
#                    all      0.698          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/30      1.79G   0.007989          4        224: 100% ━━━━━━━━━━━━ 26/26 7.3it/s 3.6s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 21.2it/s 0.1s.2s
#                    all      0.703          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/30      1.79G     0.0121          4        224: 100% ━━━━━━━━━━━━ 26/26 6.6it/s 3.9s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.2s/it 3.6s0.6s4s
#                    all       0.68          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/30      1.79G    0.01198          4        224: 100% ━━━━━━━━━━━━ 26/26 6.6it/s 4.0s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.2s/it 6.5s<10.8s
#                    all      0.686          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/30      1.79G   0.005943          4        224: 100% ━━━━━━━━━━━━ 26/26 7.7it/s 3.4s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.4s/it 4.3s0.2s
#                    all      0.715          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/30      1.79G   0.001377          4        224: 100% ━━━━━━━━━━━━ 26/26 6.9it/s 3.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 20.9it/s 0.1s.2s
#                    all      0.698          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/30      1.79G   0.001965          4        224: 100% ━━━━━━━━━━━━ 26/26 6.0it/s 4.4s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.3s/it 4.0s2.4s6s
#                    all      0.692          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/30      1.79G   0.003538          4        224: 100% ━━━━━━━━━━━━ 26/26 6.7it/s 3.9s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.0s/it 5.9s9.7s
#                    all      0.709          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/30      1.79G   0.003845          4        224: 100% ━━━━━━━━━━━━ 26/26 6.9it/s 3.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.2s/it 3.5s0.2s
#                    all      0.692          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/30      1.79G   0.005223          4        224: 100% ━━━━━━━━━━━━ 26/26 6.3it/s 4.2s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 20.8it/s 0.1s.2s
#                    all      0.674          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/30      1.79G   0.003568          4        224: 100% ━━━━━━━━━━━━ 26/26 7.3it/s 3.6s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.7s/it 5.0s2.3s6s
#                    all      0.692          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       26/30      1.79G   0.002098          4        224: 100% ━━━━━━━━━━━━ 26/26 6.9it/s 3.8s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.1s/it 6.2s<10.3s
#                    all      0.686          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       27/30      1.79G  0.0009825          4        224: 100% ━━━━━━━━━━━━ 26/26 6.9it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.2s/it 3.5s0.2s
#                    all      0.698          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       28/30      1.79G    0.01254          4        224: 100% ━━━━━━━━━━━━ 26/26 7.0it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 20.2it/s 0.1s.2s
#                    all      0.709          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       29/30      1.79G    0.00281          4        224: 100% ━━━━━━━━━━━━ 26/26 7.2it/s 3.6s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.7s/it 5.2s2.5s5s
#                    all      0.709          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       30/30      1.79G   0.006633          4        224: 100% ━━━━━━━━━━━━ 26/26 7.6it/s 3.4s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.3s/it 6.9s<11.5s
#                    all      0.692          1
#
# 30 epochs completed in 0.071 hours.
# Optimizer stripped from /kaggle/working/yolo_autoaugment_model_comparison/yolo_runs/trivial_aug_yolo26m-cls/weights/last.pt, 20.9MB
# Optimizer stripped from /kaggle/working/yolo_autoaugment_model_comparison/yolo_runs/trivial_aug_yolo26m-cls/weights/best.pt, 20.9MB
#
# Validating /kaggle/working/yolo_autoaugment_model_comparison/yolo_runs/trivial_aug_yolo26m-cls/weights/best.pt...
# Ultralytics 8.4.53 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26m-cls summary (fused): 57 layers, 10,346,756 parameters, 0 gradients, 39.3 GFLOPs
# train: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/train... found 804 images in 4 classes ✅
# val: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/val... found 172 images in 4 classes ✅
# test: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/test... found 173 images in 4 classes ✅
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.7s/it 5.1s0.3s
#                    all      0.715          1
# Speed: 0.2ms preprocess, 1.0ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /kaggle/working/yolo_autoaugment_model_comparison/yolo_runs/trivial_aug_yolo26m-cls
# [GPU] TrivialAugmentWide / yolo26m-cls after YOLO train: torch CUDA memory allocated/reserved/max: 225.4/306.0/1351.9 MB | nvidia-smi util=33% mem=509/15360 MB power=32.18 W temp=74 C
# [GPU] TrivialAugmentWide / yolo26m-cls before YOLO eval: torch CUDA memory allocated/reserved/max: 225.4/306.0/1351.9 MB | nvidia-smi util=0% mem=509/15360 MB power=32.18 W temp=74 C
# [GPU] TrivialAugmentWide / yolo26m-cls after YOLO eval: torch CUDA memory allocated/reserved/max: 265.9/2790.0/1955.5 MB | nvidia-smi util=100% mem=2993/15360 MB power=67.38 W temp=72 C
# Recorded result:
#          Augmentation Augmentation Key        Model    Backend Name  \
# 0  TrivialAugmentWide      trivial_aug  yolo26m-cls  yolo26m-cls.pt
#
#    Parameters (M)  Training Time (s)  Val F1-Score  Test Accuracy  \
# 0           10.35              270.3        0.6904          0.711
#
#    Test F1-Score  Cohen Kappa  Inference Time (s)  FPS  Latency (ms)  \
# 0         0.6813       0.5986               27.16  6.4        157.01
#
#                                      Checkpoint Path Export Format  \
# 0  /kaggle/working/yolo_autoaugment_model_compari...
#
#   Export Path                                        Export Note
# 0              YOLO auto_augment=None; other augmentation kno...
# ==========================================================================================
# Training YOLO classifier: yolo11n-cls | Augmentation: TrivialAugmentWide
# ==========================================================================================
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n-cls.pt to 'yolo11n-cls.pt': 100% ━━━━━━━━━━━━ 5.5MB 66.1MB/s 0.1s
# [GPU] TrivialAugmentWide / yolo11n-cls before YOLO train: torch CUDA memory allocated/reserved/max: 65.0/308.0/1955.5 MB | nvidia-smi util=0% mem=511/15360 MB power=41.87 W temp=72 C
# WARNING ⚠️ 'crop_fraction' is deprecated and will be removed in the future.
# Ultralytics 8.4.53 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=None, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=30, erasing=0.0, exist_ok=True, fliplr=0.0, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.0, hsv_s=0.0, hsv_v=0.0, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n-cls.pt, momentum=0.937, mosaic=0.0, multi_scale=0.0, name=trivial_aug_yolo11n-cls, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/yolo_autoaugment_model_comparison/yolo_runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/yolo_autoaugment_model_comparison/yolo_runs/trivial_aug_yolo11n-cls, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.0, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.0, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/train... found 804 images in 4 classes ✅
# val: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/val... found 172 images in 4 classes ✅
# test: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/test... found 173 images in 4 classes ✅
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  10                  -1  1    335364  ultralytics.nn.modules.head.Classify         [256, 4]
# YOLO11n-cls summary: 86 layers, 1,536,228 parameters, 1,536,228 gradients, 3.3 GFLOPs
# Transferred 234/236 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 312.0±96.3 MB/s, size: 7.8 KB)
# train: Scanning /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/train... 804 images, 0 corrupt: 100% ━━━━━━━━━━━━ 804/804 337.2Mit/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1235.3±1378.3 MB/s, size: 922.1 KB)
# val: Scanning /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/trivial_aug/val... 172 images, 0 corrupt: 100% ━━━━━━━━━━━━ 172/172 8.8Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/yolo_autoaugment_model_comparison/yolo_runs/trivial_aug_yolo11n-cls
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/30     0.406G      1.283          4        224: 100% ━━━━━━━━━━━━ 26/26 7.1it/s 3.7s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 3.0s/it 8.9s<59.1s
#                    all      0.587          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/30     0.506G     0.7249          4        224: 100% ━━━━━━━━━━━━ 26/26 7.1it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.6s/it 7.9s<13.1s
#                    all      0.692          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/30     0.506G     0.3735          4        224: 100% ━━━━━━━━━━━━ 26/26 7.6it/s 3.4s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.5s/it 4.4s
#                    all      0.703          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/30     0.506G     0.2372          4        224: 100% ━━━━━━━━━━━━ 26/26 9.0it/s 2.9s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 31.0it/s 0.1s
#                    all      0.529          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/30     0.506G     0.2574          4        224: 100% ━━━━━━━━━━━━ 26/26 7.8it/s 3.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.0s/it 5.9s0.5s3s
#                    all      0.698          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/30     0.506G     0.2559          4        224: 100% ━━━━━━━━━━━━ 26/26 8.4it/s 3.1s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.7s/it 8.0s<13.3s
#                    all      0.605          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/30     0.506G     0.2138          4        224: 100% ━━━━━━━━━━━━ 26/26 8.1it/s 3.2s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.6s/it 4.8s
#                    all      0.488          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/30     0.506G     0.2168          4        224: 100% ━━━━━━━━━━━━ 26/26 8.0it/s 3.2s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 42.3it/s 0.1s
#                    all      0.657          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/30     0.506G     0.1439          4        224: 100% ━━━━━━━━━━━━ 26/26 7.7it/s 3.4s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.2s/it 6.5s1.0s2s
#                    all      0.576          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/30     0.506G      0.137          4        224: 100% ━━━━━━━━━━━━ 26/26 7.2it/s 3.6s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.8s/it 8.4s<13.9s
#                    all      0.657          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/30     0.506G    0.07193          4        224: 100% ━━━━━━━━━━━━ 26/26 8.4it/s 3.1s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.7s/it 5.1s
#                    all      0.663          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/30     0.506G    0.05908          4        224: 100% ━━━━━━━━━━━━ 26/26 7.8it/s 3.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 25.2it/s 0.1s
#                    all      0.674          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/30     0.506G    0.03253          4        224: 100% ━━━━━━━━━━━━ 26/26 7.6it/s 3.4s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.0s/it 6.1s<40.2s
#                    all      0.686          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/30     0.506G     0.1191          4        224: 100% ━━━━━━━━━━━━ 26/26 7.6it/s 3.4s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.8s/it 8.3s<13.9s
#                    all      0.657          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/30     0.506G    0.04627          4        224: 100% ━━━━━━━━━━━━ 26/26 7.1it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.5s/it 4.4s
#                    all      0.674          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/30     0.506G    0.02728          4        224: 100% ━━━━━━━━━━━━ 26/26 7.8it/s 3.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 27.8it/s 0.1s
#                    all      0.669          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/30     0.506G    0.03259          4        224: 100% ━━━━━━━━━━━━ 26/26 7.8it/s 3.4s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.2s/it 6.5s<42.9s
#                    all      0.715          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/30     0.506G    0.00554          4        224: 100% ━━━━━━━━━━━━ 26/26 6.1it/s 4.2s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.9s/it 8.7s<14.4s
#                    all      0.733          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/30     0.506G   0.003204          4        224: 100% ━━━━━━━━━━━━ 26/26 7.7it/s 3.4s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.9s/it 5.8s
#                    all      0.721          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/30     0.506G   0.002301          4        224: 100% ━━━━━━━━━━━━ 26/26 7.3it/s 3.6s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 49.3it/s 0.1s
#                    all      0.727          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/30     0.506G   0.001412          4        224: 100% ━━━━━━━━━━━━ 26/26 6.1it/s 4.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.2s/it 6.5s1.8s6s
#                    all      0.738          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/30     0.506G    0.01202          4        224: 100% ━━━━━━━━━━━━ 26/26 7.1it/s 3.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.8s/it 8.5s<14.1s
#                    all      0.756          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/30     0.506G   0.008842          4        224: 100% ━━━━━━━━━━━━ 26/26 6.9it/s 3.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.7s/it 5.0s
#                    all      0.727          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/30     0.506G   0.009936          4        224: 100% ━━━━━━━━━━━━ 26/26 8.1it/s 3.2s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 51.9it/s 0.1s
#                    all      0.703          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/30     0.506G   0.002076          4        224: 100% ━━━━━━━━━━━━ 26/26 7.8it/s 3.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.7s/it 8.0s4.1s9s
#                    all      0.733          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       26/30     0.506G   0.004127          4        224: 100% ━━━━━━━━━━━━ 26/26 7.7it/s 3.4s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.5s/it 7.6s<12.6s
#                    all      0.703          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       27/30     0.506G    0.00186          4        224: 100% ━━━━━━━━━━━━ 26/26 7.6it/s 3.4s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.8s/it 5.5s0.5s
#                    all      0.703          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       28/30     0.506G   0.007386          4        224: 100% ━━━━━━━━━━━━ 26/26 8.5it/s 3.0s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 4.8it/s 0.6s
#                    all      0.733          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       29/30     0.506G   0.001251          4        224: 100% ━━━━━━━━━━━━ 26/26 7.8it/s 3.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.6s/it 7.8s3.4s3s
#                    all      0.733          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       30/30     0.506G   0.000917          4        224: 100% ━━━━━━━━━━━━ 26/26 8.2it/s 3.2s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 2.7s/it 8.2s<13.5s
#                    all      0.715          1
#
# 30 epochs completed in 0.076 hours.
# Optimizer stripped from /kaggle/working/yolo_autoaugment_model_comparison/yolo_runs/trivial_aug_yolo11n-cls/weights/last.pt, 3.2MB
# ...
# New https://pypi.org/project/ultralytics/8.4.54 available 😃 Update with 'pip install -U ultralytics'
# WARNING ⚠️ 'crop_fraction' is deprecated and will be removed in the future.
# Ultralytics 8.4.53 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=augmix, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/augmix, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=30, erasing=0.0, exist_ok=True, fliplr=0.0, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.0, hsv_s=0.0, hsv_v=0.0, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11m-cls.pt, momentum=0.937, mosaic=0.0, multi_scale=0.0, name=augmix_yolo11m-cls, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/yolo_autoaugment_model_comparison/yolo_runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/yolo_autoaugment_model_comparison/yolo_runs/augmix_yolo11m-cls, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.0, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.0, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/augmix/train... found 804 images in 4 classes ✅
# val: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/augmix/val... found 172 images in 4 classes ✅
# test: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/augmix/test... found 173 images in 4 classes ✅
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  10                  -1  1    663044  ultralytics.nn.modules.head.Classify         [512, 4]
# YOLO11m-cls summary: 106 layers, 10,358,340 parameters, 10,358,340 gradients, 39.6 GFLOPs
# Transferred 294/296 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3398.9±133.8 MB/s, size: 892.0 KB)
# train: Scanning /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/augmix/train... 804 images, 0 corrupt: 100% ━━━━━━━━━━━━ 804/804 306.6Mit/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1116.2±1589.4 MB/s, size: 922.1 KB)
# val: Scanning /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/augmix/val... 172 images, 0 corrupt: 100% ━━━━━━━━━━━━ 172/172 9.2Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 49 weight(decay=0.0), 50 weight(decay=0.0005), 50 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/yolo_autoaugment_model_comparison/yolo_runs/augmix_yolo11m-cls
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/30      1.45G      1.185          4        224: 100% ━━━━━━━━━━━━ 26/26 3.2s/it 1:240.2ss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 15.3it/s 0.2s.2s
#                    all      0.628          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/30       1.8G     0.7703          4        224: 100% ━━━━━━━━━━━━ 26/26 1.7s/it 45.3s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.2it/s 0.2s.2s
#                    all      0.576          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/30       1.8G      0.638          4        224: 100% ━━━━━━━━━━━━ 26/26 1.9s/it 50.5s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 15.0it/s 0.2s.2s
#                    all      0.477          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/30       1.8G     0.6906          4        224: 100% ━━━━━━━━━━━━ 26/26 1.7s/it 45.1s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 18.8it/s 0.2s.2s
#                    all      0.448          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/30       1.8G     0.6941          4        224: 100% ━━━━━━━━━━━━ 26/26 2.0s/it 50.8s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 17.7it/s 0.2s.2s
#                    all      0.628          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/30       1.8G     0.6656          4        224: 100% ━━━━━━━━━━━━ 26/26 1.7s/it 43.4s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.7it/s 0.2s.2s
#                    all      0.593          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/30       1.8G     0.5704          4        224: 100% ━━━━━━━━━━━━ 26/26 1.9s/it 49.5s0.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 18.3it/s 0.2s.2s
#                    all      0.651          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/30       1.8G     0.4588          4        224: 100% ━━━━━━━━━━━━ 26/26 1.6s/it 42.4s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 20.1it/s 0.1s.2s
#                    all      0.634          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/30       1.8G      0.378          4        224: 100% ━━━━━━━━━━━━ 26/26 1.9s/it 48.4s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 14.8it/s 0.2s.3s
#                    all      0.727          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/30       1.8G     0.3035          4        224: 100% ━━━━━━━━━━━━ 26/26 1.7s/it 44.0s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 18.8it/s 0.2s.2s
#                    all      0.645          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/30       1.8G     0.2727          4        224: 100% ━━━━━━━━━━━━ 26/26 1.9s/it 50.5s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 16.4it/s 0.2s.2s
#                    all      0.733          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/30       1.8G     0.2521          4        224: 100% ━━━━━━━━━━━━ 26/26 1.7s/it 44.0s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.8it/s 0.2s.2s
#                    all      0.669          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/30       1.8G     0.3013          4        224: 100% ━━━━━━━━━━━━ 26/26 1.9s/it 49.7s0.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 18.7it/s 0.2s.2s
#                    all      0.657          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/30       1.8G     0.1668          4        224: 100% ━━━━━━━━━━━━ 26/26 1.7s/it 43.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.8it/s 0.2s.2s
#                    all      0.669          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/30       1.8G     0.1589          4        224: 100% ━━━━━━━━━━━━ 26/26 1.9s/it 48.9s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 14.6it/s 0.2s.2s
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/30       1.8G    0.09774          4        224: 100% ━━━━━━━━━━━━ 26/26 1.6s/it 42.6s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.6it/s 0.2s.2s
#                    all      0.738          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/30       1.8G    0.07656          4        224: 100% ━━━━━━━━━━━━ 26/26 1.9s/it 49.7s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 17.3it/s 0.2s.2s
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/30       1.8G    0.04626          4        224: 100% ━━━━━━━━━━━━ 26/26 1.6s/it 42.8s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 18.6it/s 0.2s.2s
#                    all      0.738          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/30       1.8G    0.05857          4        224: 100% ━━━━━━━━━━━━ 26/26 1.8s/it 47.9s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 17.4it/s 0.2s.2s
#                    all      0.767          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/30       1.8G    0.05567          4        224: 100% ━━━━━━━━━━━━ 26/26 1.6s/it 42.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 20.0it/s 0.2s.2s
#                    all      0.692          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/30       1.8G    0.04225          4        224: 100% ━━━━━━━━━━━━ 26/26 1.6s/it 41.9s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 18.0it/s 0.2s.2s
#                    all      0.744          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/30       1.8G    0.06642          4        224: 100% ━━━━━━━━━━━━ 26/26 1.7s/it 44.6s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 18.0it/s 0.2s.2s
#                    all       0.75          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/30       1.8G     0.1068          4        224: 100% ━━━━━━━━━━━━ 26/26 1.9s/it 48.6s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 18.1it/s 0.2s.2s
#                    all      0.733          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/30       1.8G    0.03895          4        224: 100% ━━━━━━━━━━━━ 26/26 1.7s/it 44.5s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.5it/s 0.2s.2s
#                    all      0.767          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/30       1.8G    0.04335          4        224: 100% ━━━━━━━━━━━━ 26/26 1.9s/it 50.6s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 17.0it/s 0.2s.2s
#                    all      0.779          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       26/30       1.8G      0.032          4        224: 100% ━━━━━━━━━━━━ 26/26 1.7s/it 44.2s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 18.6it/s 0.2s.2s
#                    all      0.773          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       27/30       1.8G    0.01603          4        224: 100% ━━━━━━━━━━━━ 26/26 1.9s/it 49.9s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 16.4it/s 0.2s.2s
#                    all      0.762          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       28/30       1.8G    0.02461          4        224: 100% ━━━━━━━━━━━━ 26/26 1.6s/it 42.0s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.9it/s 0.2s.2s
#                    all      0.756          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       29/30       1.8G    0.02308          4        224: 100% ━━━━━━━━━━━━ 26/26 1.9s/it 49.3s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 15.4it/s 0.2s.2s
#                    all      0.762          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       30/30       1.8G     0.0174          4        224: 100% ━━━━━━━━━━━━ 26/26 1.7s/it 43.1s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 20.2it/s 0.1s.2s
#                    all      0.762          1
#
# 30 epochs completed in 0.412 hours.
# Optimizer stripped from /kaggle/working/yolo_autoaugment_model_comparison/yolo_runs/augmix_yolo11m-cls/weights/last.pt, 20.9MB
# Optimizer stripped from /kaggle/working/yolo_autoaugment_model_comparison/yolo_runs/augmix_yolo11m-cls/weights/best.pt, 20.9MB
#
# Validating /kaggle/working/yolo_autoaugment_model_comparison/yolo_runs/augmix_yolo11m-cls/weights/best.pt...
# Ultralytics 8.4.53 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11m-cls summary (fused): 57 layers, 10,346,756 parameters, 0 gradients, 39.3 GFLOPs
# train: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/augmix/train... found 804 images in 4 classes ✅
# val: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/augmix/val... found 172 images in 4 classes ✅
# test: /kaggle/working/yolo_autoaugment_model_comparison/yolo_datasets/augmix/test... found 173 images in 4 classes ✅
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 11.1it/s 0.3s.3s
#                    all      0.779          1
# Speed: 0.1ms preprocess, 1.2ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /kaggle/working/yolo_autoaugment_model_comparison/yolo_runs/augmix_yolo11m-cls
# [GPU] AugMix / yolo11m-cls after YOLO train: torch CUDA memory allocated/reserved/max: 227.1/380.0/1957.6 MB | nvidia-smi util=0% mem=583/15360 MB power=31.59 W temp=71 C
# [GPU] AugMix / yolo11m-cls before YOLO eval: torch CUDA memory allocated/reserved/max: 227.1/380.0/1957.6 MB | nvidia-smi util=0% mem=583/15360 MB power=31.59 W temp=71 C
# [GPU] AugMix / yolo11m-cls after YOLO eval: torch CUDA memory allocated/reserved/max: 268.8/2862.0/1958.4 MB | nvidia-smi util=100% mem=3065/15360 MB power=70.28 W temp=70 C
# Recorded result:
#   Augmentation Augmentation Key        Model    Backend Name  Parameters (M)  \
# 0       AugMix           augmix  yolo11m-cls  yolo11m-cls.pt           10.35
#
#    Training Time (s)  Val F1-Score  Test Accuracy  Test F1-Score  Cohen Kappa  \
# 0             1494.3          0.76         0.7572         0.7336       0.6669
#
#    Inference Time (s)  FPS  Latency (ms)  \
# 0               29.13  5.9        168.39
#
#                                      Checkpoint Path Export Format  \
# 0  /kaggle/working/yolo_autoaugment_model_compari...
#
#   Export Path                                        Export Note
# 0              YOLO auto_augment=augmix; other augmentation k...

# %% [markdown]
# ## 6. Combined Results

# %%
df_summary = pd.DataFrame(comparison_results)
metric_columns = [
    "Augmentation",
    "Model",
    "Parameters (M)",
    "Training Time (s)",
    "Val F1-Score",
    "Test Accuracy",
    "Test F1-Score",
    "Cohen Kappa",
    "Inference Time (s)",
    "FPS",
    "Latency (ms)",
]

if not df_summary.empty:
    df_summary = df_summary.sort_values(by="Test F1-Score", ascending=False, na_position="last").reset_index(drop=True)
    print("\n" + "=" * 90)
    print("YOLO AUTO-AUGMENTATION MODEL PERFORMANCE SUMMARY: SHRIMP DISEASE CLASSIFICATION")
    print("=" * 90)
    display(df_summary[metric_columns])

    summary_csv = REPORT_DIR / "yolo_autoaugment_model_comparison_summary.csv"
    summary_json = REPORT_DIR / "yolo_autoaugment_model_comparison_summary.json"
    metrics_csv = REPORT_DIR / "yolo_autoaugment_model_comparison_metrics_table.csv"
    df_summary.to_csv(summary_csv, index=False)
    df_summary.to_json(summary_json, orient="records", indent=2)
    df_summary[metric_columns].to_csv(metrics_csv, index=False)
    print(f"Saved full summary CSV: {summary_csv}")
    print(f"Saved full summary JSON: {summary_json}")
    print(f"Saved metrics-only CSV: {metrics_csv}")

    best_by_aug = (
        df_summary.sort_values(by="Test F1-Score", ascending=False, na_position="last")
        .groupby("Augmentation", as_index=False)
        .head(1)
        .reset_index(drop=True)
    )
    print("\nBest YOLO model per augmentation policy:")
    display(best_by_aug[metric_columns])
else:
    print("No model results were produced.")
# Out:
# ==========================================================================================
# YOLO AUTO-AUGMENTATION MODEL PERFORMANCE SUMMARY: SHRIMP DISEASE CLASSIFICATION
# ==========================================================================================
#           Augmentation        Model  Parameters (M)  Training Time (s)  \
# 0          RandAugment  yolo26n-cls            1.53             1449.3
# 1          RandAugment  yolo26m-cls           10.35             1449.7
# 2          RandAugment  yolo11m-cls           10.35             1450.1
# 3          RandAugment  yolo11n-cls            1.53             1442.5
# 4               AugMix  yolo26m-cls           10.35             1389.8
# 5               AugMix  yolo26n-cls            1.53             1537.3
# 6               AugMix  yolo11n-cls            1.53             1425.9
# 7   TrivialAugmentWide  yolo11n-cls            1.53              288.1
# 8               AugMix  yolo11m-cls           10.35             1494.3
# 9   TrivialAugmentWide  yolo26m-cls           10.35              270.3
# 10  TrivialAugmentWide  yolo11m-cls           10.35              176.9
# 11  TrivialAugmentWide  yolo26n-cls            1.53              244.3
#
#     Val F1-Score  Test Accuracy  Test F1-Score  Cohen Kappa  \
# 0         0.7851         0.8324         0.8266       0.7725
# 1         0.8326         0.8266         0.8177       0.7615
# 2         0.8143         0.8208         0.8156       0.7569
# 3         0.7916         0.8208         0.8045       0.7554
# 4         0.7531         0.7919         0.7717       0.7146
# 5         0.7752         0.7803         0.7628       0.6997
# 6         0.7735         0.7688         0.7545       0.6831
# 7         0.7271         0.7688         0.7342       0.6804
# 8         0.7600         0.7572         0.7336       0.6669
# 9         0.6904         0.7110         0.6813       0.5986
# 10        0.7003         0.6821         0.6484       0.5678
# 11        0.6621         0.6590         0.6074       0.5228
#
#     Inference Time (s)  FPS  Latency (ms)
# 0                30.21  5.7        174.63
# 1                30.60  5.7        176.89
# 2                30.44  5.7        175.95
# 3                29.39  5.9        169.89
# 4                27.16  6.4        156.98
# 5                28.54  6.1        164.96
# 6                29.20  5.9        168.77
# 7                30.84  5.6        178.26
# 8                29.13  5.9        168.39
# 9                27.16  6.4        157.01
# 10               31.43  5.5        181.70
# 11               27.50  6.3        158.95
# Saved full summary CSV: /kaggle/working/yolo_autoaugment_model_comparison/reports/yolo_autoaugment_model_comparison_summary.csv
# Saved full summary JSON: /kaggle/working/yolo_autoaugment_model_comparison/reports/yolo_autoaugment_model_comparison_summary.json
# Saved metrics-only CSV: /kaggle/working/yolo_autoaugment_model_comparison/reports/yolo_autoaugment_model_comparison_metrics_table.csv
#
# Best YOLO model per augmentation policy:
#          Augmentation        Model  Parameters (M)  Training Time (s)  \
# 0         RandAugment  yolo26n-cls            1.53             1449.3
# 1              AugMix  yolo26m-cls           10.35             1389.8
# 2  TrivialAugmentWide  yolo11n-cls            1.53              288.1
#
#    Val F1-Score  Test Accuracy  Test F1-Score  Cohen Kappa  \
# 0        0.7851         0.8324         0.8266       0.7725
# 1        0.7531         0.7919         0.7717       0.7146
# 2        0.7271         0.7688         0.7342       0.6804
#
#    Inference Time (s)  FPS  Latency (ms)
# 0               30.21  5.7        174.63
# 1               27.16  6.4        156.98
# 2               30.84  5.6        178.26

# %%
import shutil
import os

# Define source and target
src_folder = "/kaggle/working/yolo_autoaugment_model_comparison/yolo_runs"
zip_path = "/kaggle/working/yolo_autoaugment_model_comparison_yolo_runs.zip"

# Zip the folder
if os.path.exists(src_folder):
    shutil.make_archive(zip_path.replace(".zip", ""), 'zip', src_folder)
    print(f"Zipped folder at: {zip_path}")
else:
    print("Source folder not found:", src_folder)
# Out:
# Zipped folder at: /kaggle/working/yolo_autoaugment_model_comparison_yolo_runs.zip
