# %% [markdown]
# # RECSRA Mobile-On-Shore RTX 4090 Benchmark
# This notebook runs the YOLO11s baseline and YOLO11s-RECSRA sequentially on RTX 4090 GPU 0.

# %%
from pathlib import Path
import subprocess
pkg = Path('/home/drnguyenvinh/notebooks/RECSRA_Mobile10_RTX4090_Benchmark')
assert (pkg / 'run_rtx4090.sh').is_file(), pkg
print(pkg)

# %%
subprocess.run(['bash', str(pkg / 'run_rtx4090.sh')], check=True)

# %%
import pandas as pd
out = Path('/home/drnguyenvinh/notebooks/recsra_mobile10_output_rtx4090')
display(pd.read_csv(out / 'top5_selected_noise_families.csv'))
print(out / 'RECSRA_mobile10_RTX4090_final_results.zip')
print((out / 'RECSRA_mobile10_RTX4090_final_results.zip.sha256').read_text())
